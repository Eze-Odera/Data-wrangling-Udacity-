# %% [markdown]
# # PROJECT DETAILS

# %% [markdown]
# Project Steps Overview
# The tasks in this project are as follows:
#
# Step 1: Gathering data
#
# Step 2: Assessing data
#
# Step 3: Cleaning data
#
# Step 4: Storing data
#
# Step 5: Analyzing, and visualizing data
#
# Step 6: Reporting

# %% [markdown]
# ---

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# The dataset i will be dealing with is the tweet archive of Twitter user @dog_rates, also known as WeRateDogs.

# %% [markdown]
# The WeRateDog is a Twitter archive containing over 5000 tweets, which have been filtered to create the enhanced archive that forms the basis of this analysis.

# %% [markdown]
# ## THE GOAL

# %% [markdown]
# The goal of this project is to wrangle the data, gather, assess, clean and tidy the dataset in other to provide meaningful and intelligent analyses and visualizations.

# %% [markdown]
# ---

# %% [markdown]
# ## INSTALL NECCESSARY LIBRARIES

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (4.10.1)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from tweepy) (2.27.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from tweepy) (3.2.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.12)

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from seaborn) (1.22.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from seaborn) (1.4.1)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.1->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.1->seaborn) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.1->seaborn) (1.4.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.1->seaborn) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.1->seaborn) (4.31.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas>=0.25->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (1.8.2.2)
# Requirement already satisfied: pillow in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from wordcloud) (1.22.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib->wordcloud) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib->wordcloud) (4.31.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib->wordcloud) (1.4.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: six>=1.5 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: tqdm in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nltk>=3.1->textblob) (4.63.1)
# Requirement already satisfied: click in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nltk>=3.1->textblob) (8.1.3)
# Requirement already satisfied: joblib in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nltk>=3.1->textblob) (2022.9.13)
# Requirement already satisfied: colorama in c:\users\derae\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## IMPORT ALL NECCESSARY LIBRARIES

# %%
import pandas as pd
from pandas import read_html
import html5lib
import numpy as np
import requests 
import tweepy
import datetime
import re
import os
import json
import time
import warnings

import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline

import seaborn as sns

print("Done")
# Out:
# Done

# %% [markdown]
# ---

# %% [markdown]
# # Step 1: Gathering Data

# %% [markdown]
# 1. Twitter archive file
# 2. Tweet image predictions
# 3. Twitter API & JSON

# %% [markdown]
# ## 1. Twitter Archieve

# %% [markdown]
# This data was downloaded manually form the udacity server

# %% [markdown]
# #### Load data as dftwitter

# %%
# Load the twitter archieve file into a DataFrame
dftwitter = pd.read_csv('twitter-archive-enhanced.csv')

# %%
dftwitter.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
dftwitter.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  name doggo floofer pupper puppo
# 2351                  10  None  None    None   None  None
# 2352                  10     a  None    None   None  None
# 2353                  10     a  None    None   None  None
# 2354                  10     a  None    None   None  None
# 2355                  10  None  None    None   None  None

# %%
dftwitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
dftwitter.shape
# Out:
# (2356, 17)

# %%
dftwitter.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Tweet Image Prediction

# %% [markdown]
# This file is hosted on Udacity servers and is downloaded programmatical using the request library and the URL below:
# "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"

# %%
# Downloading URL programatically
url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# HTTP status code 200 indicates the request has succeeded

# %%
with open('image-predictions.tsv', mode ='wb') as file:
    file.write(response.content)

# %%
#Read TSV file
dfimage = pd.read_csv('image-predictions.tsv', sep='\t' )

# %%
ls * tsv
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D085-624E
#
#  Directory of C:\Users\derae\Data Analysis\Project 2_2
#
#
#  Directory of C:\Users\derae\Data Analysis\Project 2_2
#
# 09/23/2022  11:38 AM    <DIR>          .
# 09/23/2022  11:38 AM    <DIR>          ..
# 09/23/2022  11:36 AM    <DIR>          .ipynb_checkpoints
# 09/23/2022  11:38 AM           335,079 image-predictions.tsv
# 09/23/2022  11:38 AM           609,270 Project 2_2.ipynb
# 09/17/2022  09:03 AM           915,692 twitter-archive-enhanced.csv
#                3 File(s)      1,860,041 bytes
#                3 Dir(s)  405,230,379,008 bytes free

# %%
dfimage.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
dfimage.tail()
# Out:
#                 tweet_id                                          jpg_url  \
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2070        2       basset  0.555712    True    English_springer  0.225770
# 2071        1  paper_towel  0.170278   False  Labrador_retriever  0.168086
# 2072        1    Chihuahua  0.716012    True            malamute  0.078253
# 2073        1    Chihuahua  0.323581    True            Pekinese  0.090647
# 2074        1       orange  0.097049   False               bagel  0.085851
#
#       p2_dog                           p3   p3_conf  p3_dog
# 2070    True  German_short-haired_pointer  0.175219    True
# 2071    True                      spatula  0.040836   False
# 2072    True                       kelpie  0.031379    True
# 2073    True                     papillon  0.068957    True
# 2074   False                       banana  0.076110   False

# %%
dfimage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
dfimage.shape
# Out:
# (2075, 12)

# %%
dfimage.columns
# Out:
# Index(['tweet_id', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %%
dfimage.isnull().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Twitter API & JSON

# %% [markdown]
# This data was gotten from twitter by querying the Twitter API using Python's Tweepy library to get the entire set of JSON data for each of the tweets in the WeRateDogs Twitter archive.

# %% [markdown]
# ### Twitter API keys, Secrets, and Tokens

# %%
CONSUMER_KEY = 'HIDDEN'
CONSUMER_SECRET = 'HIDDEN'
OAUTH_TOKEN = 'HIDDEN'
OAUTH_TOKEN_SECRET = 'HIDDEN'

# %%
# Create the Twitter API object and set rate limit params

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

api = tweepy.API(auth)

# %% [markdown]
# I encounterd some challenges while carrying out this process so i had to use from the reasource already provided in Udacity server from the URL below:
# 'https://video.udacity-data.com/topher/2018/November/5be5fb7d_tweet-json/tweet-json.txt'

# %%
# Downloading URL Programaticall
url = 'https://video.udacity-data.com/topher/2018/November/5be5fb7d_tweet-json/tweet-json.txt'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# HTTP status code 200 indicates the request has succeeded

# %%
# Save HTML to file

json_list =[]
with open("tweet-json.txt",'r') as file:
    for line in file:
        tweets = json.loads(line)
        tweet_id = tweets['id']
        favorite_count = tweets['favorite_count']
        retweet_count = tweets['retweet_count']
        
        json_list.append({'tweet_id':tweet_id,
                          'favorite_count':favorite_count,
                          'retweet_count':retweet_count,
                         })

# %%
dfjtweet = pd.DataFrame(json_list, columns = ['tweet_id','favorite_count','retweet_count'])

# %%
dfjtweet.head()
# Out:
#              tweet_id  favorite_count  retweet_count
# 0  892420643555336193           39467           8853
# 1  892177421306343426           33819           6514
# 2  891815181378084864           25461           4328
# 3  891689557279858688           42908           8964
# 4  891327558926688256           41048           9774

# %%
dfjtweet.tail()
# Out:
#                 tweet_id  favorite_count  retweet_count
# 2349  666049248165822465             111             41
# 2350  666044226329800704             311            147
# 2351  666033412701032449             128             47
# 2352  666029285002620928             132             48
# 2353  666020888022790149            2535            532

# %%
dfjtweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   int64
#  1   favorite_count  2354 non-null   int64
#  2   retweet_count   2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %%
dfjtweet.isnull().sum()
# Out:
# tweet_id          0
# favorite_count    0
# retweet_count     0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Step 2: Assessing data

# %% [markdown]
# In this section, i assembled all three data that i have gathered earlier both visually and programmatically

# %% [markdown]
# Here i am going to be Inspecting the detaset for two things:
#
# - Data quality issues(i.e. content issues)
# - Lack of tidiness (i.e. Structural issues).

# %% [markdown]
# ## Visual Inspection

# %%
dftwitter
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 17 columns]

# %%
dfimage
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# 0           1  Welsh_springer_spaniel  0.465074    True              collie
# 1           1                 redbone  0.506826    True  miniature_pinscher
# 2           1         German_shepherd  0.596461    True            malinois
# 3           1     Rhodesian_ridgeback  0.408143    True             redbone
# 4           1      miniature_pinscher  0.560311    True          Rottweiler
# ...       ...                     ...       ...     ...                 ...
# 2070        2                  basset  0.555712    True    English_springer
# 2071        1             paper_towel  0.170278   False  Labrador_retriever
# 2072        1               Chihuahua  0.716012    True            malamute
# 2073        1               Chihuahua  0.323581    True            Pekinese
# 2074        1                  orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0     0.156665    True            Shetland_sheepdog  0.061428    True
# 1     0.074192    True          Rhodesian_ridgeback  0.072010    True
# 2     0.138584    True                   bloodhound  0.116197    True
# 3     0.360687    True           miniature_pinscher  0.222752    True
# 4     0.243682    True                     Doberman  0.154629    True
# ...        ...     ...                          ...       ...     ...
# 2070  0.225770    True  German_short-haired_pointer  0.175219    True
# 2071  0.168086    True                      spatula  0.040836   False
# 2072  0.078253    True                       kelpie  0.031379    True
# 2073  0.090647    True                     papillon  0.068957    True
# 2074  0.085851   False                       banana  0.076110   False
#
# [2075 rows x 12 columns]

# %%
dfjtweet
# Out:
#                 tweet_id  favorite_count  retweet_count
# 0     892420643555336193           39467           8853
# 1     892177421306343426           33819           6514
# 2     891815181378084864           25461           4328
# 3     891689557279858688           42908           8964
# 4     891327558926688256           41048           9774
# ...                  ...             ...            ...
# 2349  666049248165822465             111             41
# 2350  666044226329800704             311            147
# 2351  666033412701032449             128             47
# 2352  666029285002620928             132             48
# 2353  666020888022790149            2535            532
#
# [2354 rows x 3 columns]

# %% [markdown]
# I also had to view the file from a text editor outside pandas for proper visualization

# %% [markdown]
# ---

# %% [markdown]
# ## Programatic Inspection

# %%
dftwitter.shape
# Out:
# (2356, 17)

# %%
dftwitter.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
dftwitter.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
dftwitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
dftwitter.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# 25%           7.186315e+17              4.196984e+09         10.000000
# 50%           7.804657e+17              4.196984e+09         11.000000
# 75%           8.203146e+17              4.196984e+09         12.000000
# max           8.874740e+17              7.874618e+17       1776.000000
#
#        rating_denominator
# count         2356.000000
# mean            10.455433
# std              6.745237
# min              0.000000
# 25%             10.000000
# 50%             10.000000
# 75%             10.000000
# max            170.000000

# %%
# Check for duplicacy
dftwitter.duplicated().sum()
# Out:
# 0

# %% [markdown]
# This shows clearly that we have no duplicated data

# %%
# View the sorces of data and their value count
dftwitter['source'].value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %% [markdown]
# This shows the data came from 4 sources and the first one "http://twitter.com/download/iphone" has the highest value count which is from the users iphone.

# %% [markdown]
# ## rating_numerator and rating_denominator

# %%
dftwitter[['rating_numerator','rating_denominator']].describe()
# Out:
#        rating_numerator  rating_denominator
# count       2356.000000         2356.000000
# mean          13.126486           10.455433
# std           45.876648            6.745237
# min            0.000000            0.000000
# 25%           10.000000           10.000000
# 50%           11.000000           10.000000
# 75%           12.000000           10.000000
# max         1776.000000          170.000000

# %% [markdown]
# - The max values are huge: 1776,170
# - The minimum is 0 for both

# %%
dftwitter.rating_denominator.value_counts().sort_index(ascending = False)
# Out:
# 170       1
# 150       1
# 130       1
# 120       1
# 110       1
# 90        1
# 80        2
# 70        1
# 50        3
# 40        1
# 20        2
# 16        1
# 15        1
# 11        3
# 10     2333
# 7         1
# 2         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
sum(dftwitter.rating_denominator != 10)
# Out:
# 23

# %% [markdown]
# ### NOTE:

# %% [markdown]
# Many large numbers are multiples of 10 (2333)

# %% [markdown]
# When looking at some of those tweets we see that there is more than 1 dog in the photo.

# %% [markdown]
# Ignoring the retweets and replies we have the following list below

# %%
# display tweets that do NOT have denominator of 10,
# and are NOT replies and are NOT retweets
den_find = (dftwitter.rating_denominator != 10) & \
            dftwitter.in_reply_to_status_id.isna() & \
            dftwitter.retweeted_status_id.isna()

den_cols = ['text', 'tweet_id', 'rating_numerator', 'rating_denominator']
dftwitter[den_find][den_cols]
# Out:
#                                                    text            tweet_id  \
# 433   The floofs have been released I repeat the flo...  820690176645140481
# 516   Meet Sam. She smiles 24/7 &amp; secretly aspir...  810984652412424192
# 902   Why does this never happen at my front door......  758467244762497024
# 1068  After so many requests, this is Bretagne. She ...  740373189193256964
# 1120  Say hello to this unbelievably well behaved sq...  731156023742988288
# 1165  Happy 4/20 from the squad! 13/10 for all https...  722974582966214656
# 1202  This is Bluebert. He just saw that both #Final...  716439118184652801
# 1228  Happy Saturday here's 9 puppers on a bench. 99...  713900603437621249
# 1254  Here's a brigade of puppers. All look very pre...  710658690886586372
# 1274  From left to right:\nCletus, Jerome, Alejandro...  709198395643068416
# 1351  Here is a whole flock of puppers.  60/50 I'll ...  704054845121142784
# 1433  Happy Wednesday here's a bucket of pups. 44/40...  697463031882764288
# 1635  Someone help the girl is being mugged. Several...  684222868335505415
# 1662  This is Darrel. He just robbed a 7/11 and is i...  682962037429899265
# 1779  IT'S PUPPERGEDDON. Total of 144/120 ...I think...  677716515794329600
# 1843  Here we have an entire platoon of puppers. Tot...  675853064436391936
# 2335  This is an Albanian 3 1/2 legged  Episcopalian...  666287406224695296
#
#       rating_numerator  rating_denominator
# 433                 84                  70
# 516                 24                   7
# 902                165                 150
# 1068                 9                  11
# 1120               204                 170
# 1165                 4                  20
# 1202                50                  50
# 1228                99                  90
# 1254                80                  80
# 1274                45                  50
# 1351                60                  50
# 1433                44                  40
# 1635               121                 110
# 1662                 7                  11
# 1779               144                 120
# 1843                88                  80
# 2335                 1                   2

# %%
sum(den_find)
# Out:
# 17

# %% [markdown]
# ## NOTE:

# %% [markdown]
# Ignoring the replies and retweets, there are 17 tweets with denominators that aren't 10.

# %% [markdown]
# ## Rating_numerator

# %%
# Rating numerator vlaues
dftwitter.rating_numerator.value_counts().sort_index()
# Out:
# 0         2
# 1         9
# 2         9
# 3        19
# 4        17
# 5        37
# 6        32
# 7        55
# 8       102
# 9       158
# 10      461
# 11      464
# 12      558
# 13      351
# 14       54
# 15        2
# 17        1
# 20        1
# 24        1
# 26        1
# 27        1
# 44        1
# 45        1
# 50        1
# 60        1
# 75        2
# 80        1
# 84        1
# 88        1
# 99        1
# 121       1
# 143       1
# 144       1
# 165       1
# 182       1
# 204       1
# 420       2
# 666       1
# 960       1
# 1776      1
# Name: rating_numerator, dtype: int64

# %%
sum(dftwitter.rating_numerator >= 15)
# Out:
# 28

# %% [markdown]
# ## NOTES:

# %% [markdown]
# The output above shows ALL the rating_numerator values, showing a count of 28 tweets with numerator >= 15. Next, looking at ONLY those ratings with denominators = 10, the results are as follows:

# %%
df_tweets_den_10 = dftwitter[dftwitter.rating_denominator == 10]
df_tweets_den_10.rating_numerator.value_counts().sort_index(ascending = False)
# Out:
# 1776      1
# 666       1
# 420       2
# 182       1
# 75        2
# 27        1
# 26        1
# 17        1
# 15        2
# 14       54
# 13      351
# 12      558
# 11      463
# 10      461
# 9       156
# 8       102
# 7        54
# 6        32
# 5        37
# 4        15
# 3        19
# 2         9
# 1         8
# 0         2
# Name: rating_numerator, dtype: int64

# %%
sum(df_tweets_den_10.rating_numerator >= 15)
# Out:
# 12

# %% [markdown]
# ## NOTES:

# %% [markdown]
# Looking ONLY at tweets that have denominators = 10, there are 12 with numerators >= 15. Picking 15 as the lower boundary because it's got just 2 counts, while 14 has a count of 54.

# %%
# display tweets with numerator >= 15 that DO have denominator of 10,
# and are NOT replies and are NOT retweets
den_find = (dftwitter.rating_denominator == 10) & \
            (dftwitter.rating_numerator >= 15) & \
            dftwitter.in_reply_to_status_id.isna() & \
            dftwitter.retweeted_status_id.isna()

den_cols = ['text', 'tweet_id', 'rating_numerator', 'rating_denominator']
dftwitter[den_find][den_cols]
# Out:
#                                                    text            tweet_id  \
# 695   This is Logan, the Chow who lived. He solemnly...  786709082849828864
# 763   This is Sophie. She's a Jubilant Bush Pupper. ...  778027034220126208
# 979   This is Atticus. He's quite simply America af....  749981277374128128
# 1712  Here we have uncovered an entire battalion of ...  680494726643068929
# 2074  After so many requests... here you go.\n\nGood...  670842764863651840
#
#       rating_numerator  rating_denominator
# 695                 75                  10
# 763                 27                  10
# 979               1776                  10
# 1712                26                  10
# 2074               420                  10

# %%
# display tweets with numerator = 0 that DO have denominator of 10,
# and are NOT replies and are NOT retweets
den_find = (dftwitter.rating_denominator == 10) & \
            (dftwitter.rating_numerator == 0) & \
            dftwitter.in_reply_to_status_id.isna() & \
            dftwitter.retweeted_status_id.isna()

den_cols = ['text', 'tweet_id', 'rating_numerator', 'rating_denominator']
dftwitter[den_find][den_cols]
# Out:
#                                                   text            tweet_id  \
# 315  When you're so blinded by your systematic plag...  835152434251116546
#
#      rating_numerator  rating_denominator
# 315                 0                  10

# %% [markdown]
# # Check for retweets
# len(dftwitter[dftwitter.retweeted_status_id.isnull() == False])

# %% [markdown]
# ## OBSERVATIONS

# %% [markdown]
# ### QUALITY

# %% [markdown]
# 1. Retweeted columns are not needed
# 2. in_reply_to_status_id and the in_reply_to_user_id not needed
# 3. The Dog Names are faulty
# 4. Tweets with missing data in expanded_urls (links to the tweet).
# 5. The rating denominator needs to be fixed
# 6. Timestamp column needs to be a datetime variable
#     - The ID vatiable are sometimes integers and sometimes as floats
#     - in_reply_to and retweeted_staus variables are numeric
#     - retweets are present in the data
# 7. There are only 4 types of values in the source column, and they can be simplified by using the display string portion just before the final "<\a>":
#
#     - Twitter for iPhone
#     - Vine - Make a Scene
#     - Twitter Web Client
#     - TweetDeck

# %% [markdown]
# ### STRUCTURE (TIDINESS)

# %% [markdown]
# 1. All columns related to “retweets” will be empty (we're not interested in retweets)
# 2. All columns related to replies will be droped
# 3. There are 4 columns for dog stage

# %% [markdown]
# ## NOTE:

# %% [markdown]
# ### The quality and tidiness issues for the rest of the dataset are listed below

# %% [markdown]
# ---

# %% [markdown]
# # Image Predictions

# %%
dfimage
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# 0           1  Welsh_springer_spaniel  0.465074    True              collie
# 1           1                 redbone  0.506826    True  miniature_pinscher
# 2           1         German_shepherd  0.596461    True            malinois
# 3           1     Rhodesian_ridgeback  0.408143    True             redbone
# 4           1      miniature_pinscher  0.560311    True          Rottweiler
# ...       ...                     ...       ...     ...                 ...
# 2070        2                  basset  0.555712    True    English_springer
# 2071        1             paper_towel  0.170278   False  Labrador_retriever
# 2072        1               Chihuahua  0.716012    True            malamute
# 2073        1               Chihuahua  0.323581    True            Pekinese
# 2074        1                  orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0     0.156665    True            Shetland_sheepdog  0.061428    True
# 1     0.074192    True          Rhodesian_ridgeback  0.072010    True
# 2     0.138584    True                   bloodhound  0.116197    True
# 3     0.360687    True           miniature_pinscher  0.222752    True
# 4     0.243682    True                     Doberman  0.154629    True
# ...        ...     ...                          ...       ...     ...
# 2070  0.225770    True  German_short-haired_pointer  0.175219    True
# 2071  0.168086    True                      spatula  0.040836   False
# 2072  0.078253    True                       kelpie  0.031379    True
# 2073  0.090647    True                     papillon  0.068957    True
# 2074  0.085851   False                       banana  0.076110   False
#
# [2075 rows x 12 columns]

# %%
dfimage.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
dfimage.tail()
# Out:
#                 tweet_id                                          jpg_url  \
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2070        2       basset  0.555712    True    English_springer  0.225770
# 2071        1  paper_towel  0.170278   False  Labrador_retriever  0.168086
# 2072        1    Chihuahua  0.716012    True            malamute  0.078253
# 2073        1    Chihuahua  0.323581    True            Pekinese  0.090647
# 2074        1       orange  0.097049   False               bagel  0.085851
#
#       p2_dog                           p3   p3_conf  p3_dog
# 2070    True  German_short-haired_pointer  0.175219    True
# 2071    True                      spatula  0.040836   False
# 2072    True                       kelpie  0.031379    True
# 2073    True                     papillon  0.068957    True
# 2074   False                       banana  0.076110   False

# %%
dfimage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
dfimage.shape
# Out:
# (2075, 12)

# %%
sum(dfimage.duplicated())
# Out:
# 0

# %% [markdown]
# No duplicate values

# %%
sum(dfimage.jpg_url.duplicated()==True)
# Out:
# 66

# %%
dfimage['img_num'].value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %%
dfimage.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %% [markdown]
# ## OBSERVATIONS

# %% [markdown]
# 8. Column names needs to be improved, There are underscores in p1, p2, p3 tweet_id are not categorical (string) 2075 tweet ids present

# %% [markdown]
# ---

# %% [markdown]
# ## JSON File

# %%
dfjtweet.head()
# Out:
#              tweet_id  favorite_count  retweet_count
# 0  892420643555336193           39467           8853
# 1  892177421306343426           33819           6514
# 2  891815181378084864           25461           4328
# 3  891689557279858688           42908           8964
# 4  891327558926688256           41048           9774

# %%
dfjtweet.tail()
# Out:
#                 tweet_id  favorite_count  retweet_count
# 2349  666049248165822465             111             41
# 2350  666044226329800704             311            147
# 2351  666033412701032449             128             47
# 2352  666029285002620928             132             48
# 2353  666020888022790149            2535            532

# %%
dfjtweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   int64
#  1   favorite_count  2354 non-null   int64
#  2   retweet_count   2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %%
dfjtweet.describe()
# Out:
#            tweet_id  favorite_count  retweet_count
# count  2.354000e+03     2354.000000    2354.000000
# mean   7.426978e+17     8080.968564    3164.797366
# std    6.852812e+16    11814.771334    5284.770364
# min    6.660209e+17        0.000000       0.000000
# 25%    6.783975e+17     1415.000000     624.500000
# 50%    7.194596e+17     3603.500000    1473.500000
# 75%    7.993058e+17    10122.250000    3652.000000
# max    8.924206e+17   132810.000000   79515.000000

# %%
sum(dfjtweet.duplicated()==True)
# Out:
# 0

# %% [markdown]
# ## OBSERVATIONS

# %% [markdown]
# 9. Number of missing ID's

# %% [markdown]
# ---

# %% [markdown]
# # Step 3: Cleaning data

# %% [markdown]
# ## Lets prpare a working copy of each seperate dataset

# %% [markdown]
# dftwittercopy = dftwitter.copy()
# dfimagecopy = dfimage.copy()
# dfjtweetcopy = dfjtweet.copy()
# print("Done")

# %% [markdown]
# ## Twitter Archive

# %%
dftwittercopy.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
dftwittercopy.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %% [markdown]
# ## Quality archieve #1

# %% [markdown]
# There are retweets we’re only interested in “original tweets

# %% [markdown]
# ## Quality archieve #2

# %% [markdown]
# There are reply tweets; we’re only interested in “original tweets

# %% [markdown]
# ## Tidiness archieve #1

# %% [markdown]
# All columns related to retweets will be droped

# %% [markdown]
# ## Tidiness archieve #2

# %% [markdown]
# All columns related to replies will be droped

# %% [markdown]
# ## DEFINE

# %% [markdown]
# * # Taking only Necessary Columns

# %% [markdown]
# ## CODE

# %%
dftwittercopy = dftwitter[['tweet_id', 'timestamp', 'source', 'text',
                           'expanded_urls', 'rating_numerator',
                           'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo']]

# %% [markdown]
# ## TEST

# %%
dftwittercopy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   datetime64[ns, UTC]
#  2   source              2356 non-null   object
#  3   text                2356 non-null   object
#  4   expanded_urls       2297 non-null   object
#  5   rating_numerator    2356 non-null   int64
#  6   rating_denominator  2356 non-null   int64
#  7   name                2356 non-null   object
#  8   dog_stage           2356 non-null   object
#  9   dog_breed           2356 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(3), object(6)
# memory usage: 184.2+ KB

# %%
dftwittercopy.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls',
#        'rating_numerator', 'rating_denominator', 'name', 'dog_stage',
#        'dog_breed'],
#       dtype='object')

# %% [markdown]
# ## Quality #3

# %% [markdown]
# ## DEFINE

# %% [markdown]
# Check for odd names and change to None then change all None to dog

# %% [markdown]
# ## CODE

# %%
dftwittercopy['name']
# Out:
# 0        Phineas
# 1          Tilly
# 2         Archie
# 3          Darla
# 4       Franklin
#           ...
# 2351        None
# 2352           a
# 2353           a
# 2354           a
# 2355        None
# Name: name, Length: 2356, dtype: object

# %%
nameFault = dftwittercopy[dftwittercopy.name.str.islower() == True]['name']

# %%
nameFault
# Out:
# 22       such
# 56          a
# 118     quite
# 169     quite
# 193     quite
#         ...
# 2349       an
# 2350        a
# 2352        a
# 2353        a
# 2354        a
# Name: name, Length: 109, dtype: object

# %%
nameFault.unique()
# Out:
# array(['such', 'a', 'quite', 'not', 'one', 'incredibly', 'mad', 'an',
#        'very', 'just', 'my', 'his', 'actually', 'getting', 'this',
#        'unacceptable', 'all', 'old', 'infuriating', 'the', 'by',
#        'officially', 'life', 'light', 'space'], dtype=object)

# %% [markdown]
# This clearly dont look like dog names.

# %%
for x in nameFault:
    dftwittercopy.name.replace(x, 'None', inplace = True)
# Out:
# C:\Users\derae\AppData\Local\Temp\ipykernel_11208\2690337794.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftwittercopy.name.replace(x, 'None', inplace = True)

# %%
dftwittercopy.name.unique()
# Out:
# array(['Phineas', 'Tilly', 'Archie', 'Darla', 'Franklin', 'None', 'Jax',
#        'Zoey', 'Cassie', 'Koda', 'Bruno', 'Ted', 'Stuart', 'Oliver',
#        'Jim', 'Zeke', 'Ralphus', 'Canela', 'Gerald', 'Jeffrey', 'Maya',
#        'Mingus', 'Derek', 'Roscoe', 'Waffles', 'Jimbo', 'Maisey', 'Lilly',
#        'Earl', 'Lola', 'Kevin', 'Yogi', 'Noah', 'Bella', 'Grizzwald',
#        'Rusty', 'Gus', 'Stanley', 'Alfy', 'Koko', 'Rey', 'Gary', 'Elliot',
#        'Louis', 'Jesse', 'Romeo', 'Bailey', 'Duddles', 'Jack', 'Emmy',
#        'Steven', 'Beau', 'Snoopy', 'Shadow', 'Terrance', 'Aja', 'Penny',
#        'Dante', 'Nelly', 'Ginger', 'Benedict', 'Venti', 'Goose', 'Nugget',
#        'Cash', 'Coco', 'Jed', 'Sebastian', 'Walter', 'Sierra', 'Monkey',
#        'Harry', 'Kody', 'Lassie', 'Rover', 'Napolean', 'Dawn', 'Boomer',
#        'Cody', 'Rumble', 'Clifford', 'Dewey', 'Scout', 'Gizmo', 'Cooper',
#        'Harold', 'Shikha', 'Jamesy', 'Lili', 'Sammy', 'Meatball',
#        'Paisley', 'Albus', 'Neptune', 'Quinn', 'Belle', 'Zooey', 'Dave',
#        'Jersey', 'Hobbes', 'Burt', 'Lorenzo', 'Carl', 'Jordy', 'Milky',
#        'Trooper', 'Winston', 'Sophie', 'Wyatt', 'Rosie', 'Thor', 'Oscar',
#        'Luna', 'Callie', 'Cermet', 'George', 'Marlee', 'Arya', 'Einstein',
#        'Alice', 'Rumpole', 'Benny', 'Aspen', 'Jarod', 'Wiggles',
#        'General', 'Sailor', 'Astrid', 'Iggy', 'Snoop', 'Kyle', 'Leo',
#        'Riley', 'Gidget', 'Noosh', 'Odin', 'Jerry', 'Charlie', 'Georgie',
#        'Rontu', 'Cannon', 'Furzey', 'Daisy', 'Tuck', 'Barney', 'Vixen',
#        'Jarvis', 'Mimosa', 'Pickles', 'Bungalo', 'Brady', 'Margo',
#        'Sadie', 'Hank', 'Tycho', 'Stephan', 'Indie', 'Winnie', 'Bentley',
#        'Ken', 'Max', 'Maddie', 'Pipsy', 'Monty', 'Sojourner', 'Odie',
#        'Arlo', 'Sunny', 'Vincent', 'Lucy', 'Clark', 'Mookie', 'Meera',
#        'Buddy', 'Ava', 'Rory', 'Eli', 'Ash', 'Tucker', 'Tobi', 'Chester',
#        'Wilson', 'Sunshine', 'Lipton', 'Gabby', 'Bronte', 'Poppy',
#        'Rhino', 'Willow', 'Orion', 'Eevee', 'Smiley', 'Logan', 'Moreton',
#        'Klein', 'Miguel', 'Emanuel', 'Kuyu', 'Dutch', 'Pete', 'Scooter',
#        'Reggie', 'Kyro', 'Samson', 'Loki', 'Mia', 'Malcolm', 'Dexter',
#        'Alfie', 'Fiona', 'Mutt', 'Bear', 'Doobert', 'Beebop', 'Alexander',
#        'Sailer', 'Brutus', 'Kona', 'Boots', 'Ralphie', 'Phil', 'Cupid',
#        'Pawnd', 'Pilot', 'Ike', 'Mo', 'Toby', 'Sweet', 'Pablo', 'Nala',
#        'Balto', 'Crawford', 'Gabe', 'Mattie', 'Jimison', 'Hercules',
#        'Duchess', 'Harlso', 'Sampson', 'Sundance', 'Luca', 'Flash',
#        'Finn', 'Peaches', 'Howie', 'Jazzy', 'Anna', 'Bo', 'Seamus',
#        'Wafer', 'Chelsea', 'Tom', 'Moose', 'Florence', 'Autumn', 'Dido',
#        'Eugene', 'Herschel', 'Strudel', 'Tebow', 'Chloe', 'Betty',
#        'Timber', 'Binky', 'Dudley', 'Comet', 'Larry', 'Levi', 'Akumi',
#        'Titan', 'Olivia', 'Alf', 'Oshie', 'Bruce', 'Chubbs', 'Sky',
#        'Atlas', 'Eleanor', 'Layla', 'Rocky', 'Baron', 'Tyr', 'Bauer',
#        'Swagger', 'Brandi', 'Mary', 'Moe', 'Halo', 'Augie', 'Craig',
#        'Sam', 'Hunter', 'Pavlov', 'Maximus', 'Wallace', 'Ito', 'Milo',
#        'Ollie', 'Cali', 'Lennon', 'Major', 'Duke', 'Reginald', 'Sansa',
#        'Shooter', 'Django', 'Diogi', 'Sonny', 'Philbert', 'Marley',
#        'Severus', 'Ronnie', 'Anakin', 'Bones', 'Mauve', 'Chef', 'Doc',
#        'Sobe', 'Longfellow', 'Mister', 'Iroh', 'Baloo', 'Stubert',
#        'Paull', 'Timison', 'Davey', 'Pancake', 'Tyrone', 'Snicku', 'Ruby',
#        'Brody', 'Rizzy', 'Mack', 'Butter', 'Nimbus', 'Laika', 'Dobby',
#        'Juno', 'Maude', 'Lily', 'Newt', 'Benji', 'Nida', 'Robin',
#        'Monster', 'BeBe', 'Remus', 'Mabel', 'Misty', 'Happy', 'Mosby',
#        'Maggie', 'Leela', 'Ralphy', 'Brownie', 'Meyer', 'Stella', 'Frank',
#        'Tonks', 'Lincoln', 'Oakley', 'Dale', 'Rizzo', 'Arnie', 'Pinot',
#        'Dallas', 'Hero', 'Frankie', 'Stormy', 'Mairi', 'Loomis', 'Godi',
#        'Kenny', 'Deacon', 'Timmy', 'Harper', 'Chipson', 'Combo', 'Dash',
#        'Bell', 'Hurley', 'Jay', 'Mya', 'Strider', 'Wesley', 'Solomon',
#        'Huck', 'O', 'Blue', 'Finley', 'Sprinkles', 'Heinrich',
#        'Shakespeare', 'Fizz', 'Chip', 'Grey', 'Roosevelt', 'Gromit',
#        'Willem', 'Dakota', 'Dixie', 'Al', 'Jackson', 'Carbon', 'DonDon',
#        'Kirby', 'Lou', 'Nollie', 'Chevy', 'Tito', 'Louie', 'Rupert',
#        'Rufus', 'Brudge', 'Shadoe', 'Colby', 'Angel', 'Brat', 'Tove',
#        'Aubie', 'Kota', 'Eve', 'Glenn', 'Shelby', 'Sephie', 'Bonaparte',
#        'Albert', 'Wishes', 'Rose', 'Theo', 'Rocco', 'Fido', 'Emma',
#        'Spencer', 'Lilli', 'Boston', 'Brandonald', 'Corey', 'Leonard',
#        'Chompsky', 'Beckham', 'Devón', 'Gert', 'Watson', 'Rubio', 'Keith',
#        'Dex', 'Carly', 'Ace', 'Tayzie', 'Grizzie', 'Fred', 'Gilbert',
#        'Zoe', 'Stewie', 'Calvin', 'Lilah', 'Spanky', 'Jameson', 'Piper',
#        'Atticus', 'Blu', 'Dietrich', 'Divine', 'Tripp', 'Cora', 'Huxley',
#        'Keurig', 'Bookstore', 'Linus', 'Abby', 'Shaggy', 'Shiloh',
#        'Gustav', 'Arlen', 'Percy', 'Lenox', 'Sugar', 'Harvey', 'Blanket',
#        'Geno', 'Stark', 'Beya', 'Kilo', 'Kayla', 'Maxaroni', 'Doug',
#        'Edmund', 'Aqua', 'Theodore', 'Chase', 'Rorie', 'Simba', 'Charles',
#        'Bayley', 'Axel', 'Storkson', 'Remy', 'Chadrick', 'Kellogg',
#        'Buckley', 'Livvie', 'Terry', 'Hermione', 'Ralpher', 'Aldrick',
#        'Rooney', 'Crystal', 'Ziva', 'Stefan', 'Pupcasso', 'Puff',
#        'Flurpson', 'Coleman', 'Enchilada', 'Raymond', 'Rueben',
#        'Cilantro', 'Karll', 'Sprout', 'Blitz', 'Bloop', 'Lillie',
#        'Ashleigh', 'Kreggory', 'Sarge', 'Luther', 'Ivar', 'Jangle',
#        'Schnitzel', 'Panda', 'Berkeley', 'Ralphé', 'Charleson', 'Clyde',
#        'Harnold', 'Sid', 'Pippa', 'Otis', 'Carper', 'Bowie',
#        'Alexanderson', 'Suki', 'Barclay', 'Skittle', 'Ebby', 'Flávio',
#        'Smokey', 'Link', 'Jennifur', 'Ozzy', 'Bluebert', 'Stephanus',
#        'Bubbles', 'Zeus', 'Bertson', 'Nico', 'Michelangelope', 'Siba',
#        'Calbert', 'Curtis', 'Travis', 'Thumas', 'Kanu', 'Lance', 'Opie',
#        'Kane', 'Olive', 'Chuckles', 'Staniel', 'Sora', 'Beemo', 'Gunner',
#        'Lacy', 'Tater', 'Olaf', 'Cecil', 'Vince', 'Karma', 'Billy',
#        'Walker', 'Rodney', 'Klevin', 'Malikai', 'Bobble', 'River',
#        'Jebberson', 'Remington', 'Farfle', 'Jiminus', 'Clarkus',
#        'Finnegus', 'Cupcake', 'Kathmandu', 'Ellie', 'Katie', 'Kara',
#        'Adele', 'Zara', 'Ambrose', 'Jimothy', 'Bode', 'Terrenth', 'Reese',
#        'Chesterson', 'Lucia', 'Bisquick', 'Ralphson', 'Socks', 'Rambo',
#        'Rudy', 'Fiji', 'Rilo', 'Bilbo', 'Coopson', 'Yoda', 'Millie',
#        'Chet', 'Crouton', 'Daniel', 'Kaia', 'Murphy', 'Dotsy', 'Eazy',
#        'Coops', 'Fillup', 'Miley', 'Charl', 'Reagan', 'Yukon', 'CeCe',
#        'Cuddles', 'Claude', 'Jessiga', 'Carter', 'Ole', 'Pherb',
#        'Blipson', 'Reptar', 'Trevith', 'Berb', 'Bob', 'Colin', 'Brian',
#        'Oliviér', 'Grady', 'Kobe', 'Freddery', 'Bodie', 'Dunkin', 'Wally',
#        'Tupawc', 'Amber', 'Edgar', 'Teddy', 'Kingsley', 'Brockly',
#        'Richie', 'Molly', 'Vinscent', 'Cedrick', 'Hazel', 'Lolo', 'Eriq',
#        'Phred', 'Oddie', 'Maxwell', 'Geoff', 'Covach', 'Durg', 'Fynn',
#        'Ricky', 'Herald', 'Lucky', 'Ferg', 'Trip', 'Clarence', 'Hamrick',
#        'Brad', 'Pubert', 'Frönq', 'Derby', 'Lizzie', 'Ember', 'Blakely',
#        'Opal', 'Marq', 'Kramer', 'Barry', 'Gordon', 'Baxter', 'Mona',
#        'Horace', 'Crimson', 'Birf', 'Hammond', 'Lorelei', 'Marty',
#        'Brooks', 'Petrick', 'Hubertson', 'Gerbald', 'Oreo', 'Bruiser',
#        'Perry', 'Bobby', 'Jeph', 'Obi', 'Tino', 'Kulet', 'Sweets', 'Lupe',
#        'Tiger', 'Jiminy', 'Griffin', 'Banjo', 'Brandy', 'Lulu', 'Darrel',
#        'Taco', 'Joey', 'Patrick', 'Kreg', 'Todo', 'Tess', 'Ulysses',
#        'Toffee', 'Apollo', 'Asher', 'Glacier', 'Chuck', 'Champ', 'Ozzie',
#        'Griswold', 'Cheesy', 'Moofasa', 'Hector', 'Goliath', 'Kawhi',
#        'Emmie', 'Penelope', 'Willie', 'Rinna', 'Mike', 'William',
#        'Dwight', 'Evy', 'Rascal', 'Linda', 'Tug', 'Tango', 'Grizz',
#        'Jerome', 'Crumpet', 'Jessifer', 'Izzy', 'Ralph', 'Sandy',
#        'Humphrey', 'Tassy', 'Juckson', 'Chuq', 'Tyrus', 'Karl',
#        'Godzilla', 'Vinnie', 'Kenneth', 'Herm', 'Bert', 'Striker',
#        'Donny', 'Pepper', 'Bernie', 'Buddah', 'Lenny', 'Arnold', 'Zuzu',
#        'Mollie', 'Laela', 'Tedders', 'Superpup', 'Rufio', 'Jeb', 'Rodman',
#        'Jonah', 'Chesney', 'Henry', 'Bobbay', 'Mitch', 'Kaiya', 'Acro',
#        'Aiden', 'Obie', 'Dot', 'Shnuggles', 'Kendall', 'Jeffri', 'Steve',
#        'Mac', 'Fletcher', 'Kenzie', 'Pumpkin', 'Schnozz', 'Gustaf',
#        'Cheryl', 'Ed', 'Leonidas', 'Norman', 'Caryl', 'Scott', 'Taz',
#        'Darby', 'Jackie', 'Jazz', 'Franq', 'Pippin', 'Rolf', 'Snickers',
#        'Ridley', 'Cal', 'Bradley', 'Bubba', 'Tuco', 'Patch', 'Mojo',
#        'Batdog', 'Dylan', 'Mark', 'JD', 'Alejandro', 'Scruffers', 'Pip',
#        'Julius', 'Tanner', 'Sparky', 'Anthony', 'Holly', 'Jett', 'Amy',
#        'Sage', 'Andy', 'Mason', 'Trigger', 'Antony', 'Creg', 'Traviss',
#        'Gin', 'Jeffrie', 'Danny', 'Ester', 'Pluto', 'Bloo', 'Edd',
#        'Willy', 'Herb', 'Damon', 'Peanut', 'Nigel', 'Butters', 'Sandra',
#        'Fabio', 'Randall', 'Liam', 'Tommy', 'Ben', 'Raphael', 'Julio',
#        'Andru', 'Kloey', 'Shawwn', 'Skye', 'Kollin', 'Ronduh', 'Billl',
#        'Saydee', 'Dug', 'Tessa', 'Sully', 'Kirk', 'Ralf', 'Clarq',
#        'Jaspers', 'Samsom', 'Harrison', 'Chaz', 'Jeremy', 'Jaycob',
#        'Lambeau', 'Ruffles', 'Amélie', 'Bobb', 'Banditt', 'Kevon',
#        'Winifred', 'Hanz', 'Churlie', 'Zeek', 'Timofy', 'Maks',
#        'Jomathan', 'Kallie', 'Marvin', 'Spark', 'Gòrdón', 'Jo', 'DayZ',
#        'Jareld', 'Torque', 'Ron', 'Skittles', 'Cleopatricia', 'Erik',
#        'Stu', 'Tedrick', 'Filup', 'Kial', 'Naphaniel', 'Dook', 'Hall',
#        'Philippe', 'Biden', 'Fwed', 'Genevieve', 'Joshwa', 'Bradlay',
#        'Clybe', 'Keet', 'Carll', 'Jockson', 'Josep', 'Lugan',
#        'Christoper'], dtype=object)

# %% [markdown]
# ### I will like to replace the None to dog

# %%
dftwittercopy.name.replace('None', 'Dog', inplace = True)
# Out:
# C:\Users\derae\AppData\Local\Temp\ipykernel_11208\1034294891.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftwittercopy.name.replace('None', 'Dog', inplace = True)

# %%
dftwittercopy.name.unique()
# Out:
# array(['Phineas', 'Tilly', 'Archie', 'Darla', 'Franklin', 'Dog', 'Jax',
#        'Zoey', 'Cassie', 'Koda', 'Bruno', 'Ted', 'Stuart', 'Oliver',
#        'Jim', 'Zeke', 'Ralphus', 'Canela', 'Gerald', 'Jeffrey', 'Maya',
#        'Mingus', 'Derek', 'Roscoe', 'Waffles', 'Jimbo', 'Maisey', 'Lilly',
#        'Earl', 'Lola', 'Kevin', 'Yogi', 'Noah', 'Bella', 'Grizzwald',
#        'Rusty', 'Gus', 'Stanley', 'Alfy', 'Koko', 'Rey', 'Gary', 'Elliot',
#        'Louis', 'Jesse', 'Romeo', 'Bailey', 'Duddles', 'Jack', 'Emmy',
#        'Steven', 'Beau', 'Snoopy', 'Shadow', 'Terrance', 'Aja', 'Penny',
#        'Dante', 'Nelly', 'Ginger', 'Benedict', 'Venti', 'Goose', 'Nugget',
#        'Cash', 'Coco', 'Jed', 'Sebastian', 'Walter', 'Sierra', 'Monkey',
#        'Harry', 'Kody', 'Lassie', 'Rover', 'Napolean', 'Dawn', 'Boomer',
#        'Cody', 'Rumble', 'Clifford', 'Dewey', 'Scout', 'Gizmo', 'Cooper',
#        'Harold', 'Shikha', 'Jamesy', 'Lili', 'Sammy', 'Meatball',
#        'Paisley', 'Albus', 'Neptune', 'Quinn', 'Belle', 'Zooey', 'Dave',
#        'Jersey', 'Hobbes', 'Burt', 'Lorenzo', 'Carl', 'Jordy', 'Milky',
#        'Trooper', 'Winston', 'Sophie', 'Wyatt', 'Rosie', 'Thor', 'Oscar',
#        'Luna', 'Callie', 'Cermet', 'George', 'Marlee', 'Arya', 'Einstein',
#        'Alice', 'Rumpole', 'Benny', 'Aspen', 'Jarod', 'Wiggles',
#        'General', 'Sailor', 'Astrid', 'Iggy', 'Snoop', 'Kyle', 'Leo',
#        'Riley', 'Gidget', 'Noosh', 'Odin', 'Jerry', 'Charlie', 'Georgie',
#        'Rontu', 'Cannon', 'Furzey', 'Daisy', 'Tuck', 'Barney', 'Vixen',
#        'Jarvis', 'Mimosa', 'Pickles', 'Bungalo', 'Brady', 'Margo',
#        'Sadie', 'Hank', 'Tycho', 'Stephan', 'Indie', 'Winnie', 'Bentley',
#        'Ken', 'Max', 'Maddie', 'Pipsy', 'Monty', 'Sojourner', 'Odie',
#        'Arlo', 'Sunny', 'Vincent', 'Lucy', 'Clark', 'Mookie', 'Meera',
#        'Buddy', 'Ava', 'Rory', 'Eli', 'Ash', 'Tucker', 'Tobi', 'Chester',
#        'Wilson', 'Sunshine', 'Lipton', 'Gabby', 'Bronte', 'Poppy',
#        'Rhino', 'Willow', 'Orion', 'Eevee', 'Smiley', 'Logan', 'Moreton',
#        'Klein', 'Miguel', 'Emanuel', 'Kuyu', 'Dutch', 'Pete', 'Scooter',
#        'Reggie', 'Kyro', 'Samson', 'Loki', 'Mia', 'Malcolm', 'Dexter',
#        'Alfie', 'Fiona', 'Mutt', 'Bear', 'Doobert', 'Beebop', 'Alexander',
#        'Sailer', 'Brutus', 'Kona', 'Boots', 'Ralphie', 'Phil', 'Cupid',
#        'Pawnd', 'Pilot', 'Ike', 'Mo', 'Toby', 'Sweet', 'Pablo', 'Nala',
#        'Balto', 'Crawford', 'Gabe', 'Mattie', 'Jimison', 'Hercules',
#        'Duchess', 'Harlso', 'Sampson', 'Sundance', 'Luca', 'Flash',
#        'Finn', 'Peaches', 'Howie', 'Jazzy', 'Anna', 'Bo', 'Seamus',
#        'Wafer', 'Chelsea', 'Tom', 'Moose', 'Florence', 'Autumn', 'Dido',
#        'Eugene', 'Herschel', 'Strudel', 'Tebow', 'Chloe', 'Betty',
#        'Timber', 'Binky', 'Dudley', 'Comet', 'Larry', 'Levi', 'Akumi',
#        'Titan', 'Olivia', 'Alf', 'Oshie', 'Bruce', 'Chubbs', 'Sky',
#        'Atlas', 'Eleanor', 'Layla', 'Rocky', 'Baron', 'Tyr', 'Bauer',
#        'Swagger', 'Brandi', 'Mary', 'Moe', 'Halo', 'Augie', 'Craig',
#        'Sam', 'Hunter', 'Pavlov', 'Maximus', 'Wallace', 'Ito', 'Milo',
#        'Ollie', 'Cali', 'Lennon', 'Major', 'Duke', 'Reginald', 'Sansa',
#        'Shooter', 'Django', 'Diogi', 'Sonny', 'Philbert', 'Marley',
#        'Severus', 'Ronnie', 'Anakin', 'Bones', 'Mauve', 'Chef', 'Doc',
#        'Sobe', 'Longfellow', 'Mister', 'Iroh', 'Baloo', 'Stubert',
#        'Paull', 'Timison', 'Davey', 'Pancake', 'Tyrone', 'Snicku', 'Ruby',
#        'Brody', 'Rizzy', 'Mack', 'Butter', 'Nimbus', 'Laika', 'Dobby',
#        'Juno', 'Maude', 'Lily', 'Newt', 'Benji', 'Nida', 'Robin',
#        'Monster', 'BeBe', 'Remus', 'Mabel', 'Misty', 'Happy', 'Mosby',
#        'Maggie', 'Leela', 'Ralphy', 'Brownie', 'Meyer', 'Stella', 'Frank',
#        'Tonks', 'Lincoln', 'Oakley', 'Dale', 'Rizzo', 'Arnie', 'Pinot',
#        'Dallas', 'Hero', 'Frankie', 'Stormy', 'Mairi', 'Loomis', 'Godi',
#        'Kenny', 'Deacon', 'Timmy', 'Harper', 'Chipson', 'Combo', 'Dash',
#        'Bell', 'Hurley', 'Jay', 'Mya', 'Strider', 'Wesley', 'Solomon',
#        'Huck', 'O', 'Blue', 'Finley', 'Sprinkles', 'Heinrich',
#        'Shakespeare', 'Fizz', 'Chip', 'Grey', 'Roosevelt', 'Gromit',
#        'Willem', 'Dakota', 'Dixie', 'Al', 'Jackson', 'Carbon', 'DonDon',
#        'Kirby', 'Lou', 'Nollie', 'Chevy', 'Tito', 'Louie', 'Rupert',
#        'Rufus', 'Brudge', 'Shadoe', 'Colby', 'Angel', 'Brat', 'Tove',
#        'Aubie', 'Kota', 'Eve', 'Glenn', 'Shelby', 'Sephie', 'Bonaparte',
#        'Albert', 'Wishes', 'Rose', 'Theo', 'Rocco', 'Fido', 'Emma',
#        'Spencer', 'Lilli', 'Boston', 'Brandonald', 'Corey', 'Leonard',
#        'Chompsky', 'Beckham', 'Devón', 'Gert', 'Watson', 'Rubio', 'Keith',
#        'Dex', 'Carly', 'Ace', 'Tayzie', 'Grizzie', 'Fred', 'Gilbert',
#        'Zoe', 'Stewie', 'Calvin', 'Lilah', 'Spanky', 'Jameson', 'Piper',
#        'Atticus', 'Blu', 'Dietrich', 'Divine', 'Tripp', 'Cora', 'Huxley',
#        'Keurig', 'Bookstore', 'Linus', 'Abby', 'Shaggy', 'Shiloh',
#        'Gustav', 'Arlen', 'Percy', 'Lenox', 'Sugar', 'Harvey', 'Blanket',
#        'Geno', 'Stark', 'Beya', 'Kilo', 'Kayla', 'Maxaroni', 'Doug',
#        'Edmund', 'Aqua', 'Theodore', 'Chase', 'Rorie', 'Simba', 'Charles',
#        'Bayley', 'Axel', 'Storkson', 'Remy', 'Chadrick', 'Kellogg',
#        'Buckley', 'Livvie', 'Terry', 'Hermione', 'Ralpher', 'Aldrick',
#        'Rooney', 'Crystal', 'Ziva', 'Stefan', 'Pupcasso', 'Puff',
#        'Flurpson', 'Coleman', 'Enchilada', 'Raymond', 'Rueben',
#        'Cilantro', 'Karll', 'Sprout', 'Blitz', 'Bloop', 'Lillie',
#        'Ashleigh', 'Kreggory', 'Sarge', 'Luther', 'Ivar', 'Jangle',
#        'Schnitzel', 'Panda', 'Berkeley', 'Ralphé', 'Charleson', 'Clyde',
#        'Harnold', 'Sid', 'Pippa', 'Otis', 'Carper', 'Bowie',
#        'Alexanderson', 'Suki', 'Barclay', 'Skittle', 'Ebby', 'Flávio',
#        'Smokey', 'Link', 'Jennifur', 'Ozzy', 'Bluebert', 'Stephanus',
#        'Bubbles', 'Zeus', 'Bertson', 'Nico', 'Michelangelope', 'Siba',
#        'Calbert', 'Curtis', 'Travis', 'Thumas', 'Kanu', 'Lance', 'Opie',
#        'Kane', 'Olive', 'Chuckles', 'Staniel', 'Sora', 'Beemo', 'Gunner',
#        'Lacy', 'Tater', 'Olaf', 'Cecil', 'Vince', 'Karma', 'Billy',
#        'Walker', 'Rodney', 'Klevin', 'Malikai', 'Bobble', 'River',
#        'Jebberson', 'Remington', 'Farfle', 'Jiminus', 'Clarkus',
#        'Finnegus', 'Cupcake', 'Kathmandu', 'Ellie', 'Katie', 'Kara',
#        'Adele', 'Zara', 'Ambrose', 'Jimothy', 'Bode', 'Terrenth', 'Reese',
#        'Chesterson', 'Lucia', 'Bisquick', 'Ralphson', 'Socks', 'Rambo',
#        'Rudy', 'Fiji', 'Rilo', 'Bilbo', 'Coopson', 'Yoda', 'Millie',
#        'Chet', 'Crouton', 'Daniel', 'Kaia', 'Murphy', 'Dotsy', 'Eazy',
#        'Coops', 'Fillup', 'Miley', 'Charl', 'Reagan', 'Yukon', 'CeCe',
#        'Cuddles', 'Claude', 'Jessiga', 'Carter', 'Ole', 'Pherb',
#        'Blipson', 'Reptar', 'Trevith', 'Berb', 'Bob', 'Colin', 'Brian',
#        'Oliviér', 'Grady', 'Kobe', 'Freddery', 'Bodie', 'Dunkin', 'Wally',
#        'Tupawc', 'Amber', 'Edgar', 'Teddy', 'Kingsley', 'Brockly',
#        'Richie', 'Molly', 'Vinscent', 'Cedrick', 'Hazel', 'Lolo', 'Eriq',
#        'Phred', 'Oddie', 'Maxwell', 'Geoff', 'Covach', 'Durg', 'Fynn',
#        'Ricky', 'Herald', 'Lucky', 'Ferg', 'Trip', 'Clarence', 'Hamrick',
#        'Brad', 'Pubert', 'Frönq', 'Derby', 'Lizzie', 'Ember', 'Blakely',
#        'Opal', 'Marq', 'Kramer', 'Barry', 'Gordon', 'Baxter', 'Mona',
#        'Horace', 'Crimson', 'Birf', 'Hammond', 'Lorelei', 'Marty',
#        'Brooks', 'Petrick', 'Hubertson', 'Gerbald', 'Oreo', 'Bruiser',
#        'Perry', 'Bobby', 'Jeph', 'Obi', 'Tino', 'Kulet', 'Sweets', 'Lupe',
#        'Tiger', 'Jiminy', 'Griffin', 'Banjo', 'Brandy', 'Lulu', 'Darrel',
#        'Taco', 'Joey', 'Patrick', 'Kreg', 'Todo', 'Tess', 'Ulysses',
#        'Toffee', 'Apollo', 'Asher', 'Glacier', 'Chuck', 'Champ', 'Ozzie',
#        'Griswold', 'Cheesy', 'Moofasa', 'Hector', 'Goliath', 'Kawhi',
#        'Emmie', 'Penelope', 'Willie', 'Rinna', 'Mike', 'William',
#        'Dwight', 'Evy', 'Rascal', 'Linda', 'Tug', 'Tango', 'Grizz',
#        'Jerome', 'Crumpet', 'Jessifer', 'Izzy', 'Ralph', 'Sandy',
#        'Humphrey', 'Tassy', 'Juckson', 'Chuq', 'Tyrus', 'Karl',
#        'Godzilla', 'Vinnie', 'Kenneth', 'Herm', 'Bert', 'Striker',
#        'Donny', 'Pepper', 'Bernie', 'Buddah', 'Lenny', 'Arnold', 'Zuzu',
#        'Mollie', 'Laela', 'Tedders', 'Superpup', 'Rufio', 'Jeb', 'Rodman',
#        'Jonah', 'Chesney', 'Henry', 'Bobbay', 'Mitch', 'Kaiya', 'Acro',
#        'Aiden', 'Obie', 'Dot', 'Shnuggles', 'Kendall', 'Jeffri', 'Steve',
#        'Mac', 'Fletcher', 'Kenzie', 'Pumpkin', 'Schnozz', 'Gustaf',
#        'Cheryl', 'Ed', 'Leonidas', 'Norman', 'Caryl', 'Scott', 'Taz',
#        'Darby', 'Jackie', 'Jazz', 'Franq', 'Pippin', 'Rolf', 'Snickers',
#        'Ridley', 'Cal', 'Bradley', 'Bubba', 'Tuco', 'Patch', 'Mojo',
#        'Batdog', 'Dylan', 'Mark', 'JD', 'Alejandro', 'Scruffers', 'Pip',
#        'Julius', 'Tanner', 'Sparky', 'Anthony', 'Holly', 'Jett', 'Amy',
#        'Sage', 'Andy', 'Mason', 'Trigger', 'Antony', 'Creg', 'Traviss',
#        'Gin', 'Jeffrie', 'Danny', 'Ester', 'Pluto', 'Bloo', 'Edd',
#        'Willy', 'Herb', 'Damon', 'Peanut', 'Nigel', 'Butters', 'Sandra',
#        'Fabio', 'Randall', 'Liam', 'Tommy', 'Ben', 'Raphael', 'Julio',
#        'Andru', 'Kloey', 'Shawwn', 'Skye', 'Kollin', 'Ronduh', 'Billl',
#        'Saydee', 'Dug', 'Tessa', 'Sully', 'Kirk', 'Ralf', 'Clarq',
#        'Jaspers', 'Samsom', 'Harrison', 'Chaz', 'Jeremy', 'Jaycob',
#        'Lambeau', 'Ruffles', 'Amélie', 'Bobb', 'Banditt', 'Kevon',
#        'Winifred', 'Hanz', 'Churlie', 'Zeek', 'Timofy', 'Maks',
#        'Jomathan', 'Kallie', 'Marvin', 'Spark', 'Gòrdón', 'Jo', 'DayZ',
#        'Jareld', 'Torque', 'Ron', 'Skittles', 'Cleopatricia', 'Erik',
#        'Stu', 'Tedrick', 'Filup', 'Kial', 'Naphaniel', 'Dook', 'Hall',
#        'Philippe', 'Biden', 'Fwed', 'Genevieve', 'Joshwa', 'Bradlay',
#        'Clybe', 'Keet', 'Carll', 'Jockson', 'Josep', 'Lugan',
#        'Christoper'], dtype=object)

# %% [markdown]
# ## Quality archieve #5

# %% [markdown]
# ## DEFINE

# %% [markdown]
# Assign 10 to rating denominator rating values and drop the  remaining

# %% [markdown]
# ## CODE

# %%
dftwittercopy.rating_denominator = dftwittercopy['rating_denominator'] = 10
# Out:
# C:\Users\derae\AppData\Local\Temp\ipykernel_11208\3703148832.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftwittercopy.rating_denominator = dftwittercopy['rating_denominator'] = 10

# %% [markdown]
# ## TEST

# %%
dftwittercopy.rating_denominator.unique()
# Out:
# array([10], dtype=int64)

# %% [markdown]
# ---

# %% [markdown]
# # Quality archieve #6

# %% [markdown]
# ## DEFINE

# %% [markdown]
# Convert timestamp column to date

# %% [markdown]
# ## CODE

# %%
dftwittercopy['timestamp'] = pd.to_datetime(dftwittercopy['timestamp'])
# Out:
# C:\Users\derae\AppData\Local\Temp\ipykernel_11208\2048826433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftwittercopy['timestamp'] = pd.to_datetime(dftwittercopy['timestamp'])

# %% [markdown]
# ## TEST

# %%
dftwittercopy.head()
# Out:
#              tweet_id                 timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00
# 1  892177421306343426 2017-08-01 00:17:27+00:00
# 2  891815181378084864 2017-07-31 00:18:03+00:00
# 3  891689557279858688 2017-07-30 15:58:51+00:00
# 4  891327558926688256 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %% [markdown]
# ## TIDINESS #3

# %% [markdown]
# ## DEFINE

# %% [markdown]
# Merge the the stages to one

# %% [markdown]
# ## CODE

# %%
def dog_breed(row):
    breed = []
    if row['doggo'] == 'doggo':
        breed.append('doggo')
    if row['floofer'] == 'floofer':
        breed.append('floofer')
    if row['pupper'] == 'pupper':
        breed.append('pupper')
    if row['puppo'] == 'puppo':
        breed.append('puppo')
        
    if not breed:
        return "None"
    else:
        return ','.join(breed)
    
dftwittercopy['dog_breed'] = dftwittercopy.apply(lambda row: dog_stage(row), axis = 1)
# Out:
# C:\Users\derae\AppData\Local\Temp\ipykernel_11208\2331116349.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftwittercopy['dog_breed'] = dftwittercopy.apply(lambda row: dog_stage(row), axis = 1)

# %%
#drop the columns
dftwittercopy.drop(["doggo", "floofer", "pupper", "puppo"], axis = 1, inplace = True)
# Out:
# C:\Users\derae\AppData\Local\Temp\ipykernel_11208\2918115175.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftwittercopy.drop(["doggo", "floofer", "pupper", "puppo"], axis = 1, inplace = True)

# %% [markdown]
# ## TEST

# %%
dftwittercopy.head()
# Out:
#              tweet_id                 timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00
# 1  892177421306343426 2017-08-01 00:17:27+00:00
# 2  891815181378084864 2017-07-31 00:18:03+00:00
# 3  891689557279858688 2017-07-30 15:58:51+00:00
# 4  891327558926688256 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name dog_stage dog_breed
# 0                  10   Phineas      None      None
# 1                  10     Tilly      None      None
# 2                  10    Archie      None      None
# 3                  10     Darla      None      None
# 4                  10  Franklin      None      None

# %%
pd.value_counts(dftwittercopy['dog_breed'])
# Out:
# None             1976
# pupper            245
# doggo              83
# puppo              29
# doggo,pupper       12
# floofer             9
# doggo,puppo         1
# doggo,floofer       1
# Name: dog_breed, dtype: int64

# %% [markdown]
# ## Quality archieve #4

# %% [markdown]
# ## DEFINE

# %% [markdown]
# Drop tweets with missing data in the expanded_urls

# %% [markdown]
# ## CODE

# %%
dftwittercopy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   datetime64[ns, UTC]
#  2   source              2356 non-null   object
#  3   text                2356 non-null   object
#  4   expanded_urls       2297 non-null   object
#  5   rating_numerator    2356 non-null   int64
#  6   rating_denominator  2356 non-null   int64
#  7   name                2356 non-null   object
#  8   dog_stage           2356 non-null   object
#  9   dog_breed           2356 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(3), object(6)
# memory usage: 184.2+ KB

# %%
dftwittercopy = dftwittercopy[dftwittercopy.expanded_urls.notnull()]

# %% [markdown]
# ## TEST

# %%
dftwittercopy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2297 entries, 0 to 2355
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2297 non-null   int64
#  1   timestamp           2297 non-null   datetime64[ns, UTC]
#  2   source              2297 non-null   object
#  3   text                2297 non-null   object
#  4   expanded_urls       2297 non-null   object
#  5   rating_numerator    2297 non-null   int64
#  6   rating_denominator  2297 non-null   int64
#  7   name                2297 non-null   object
#  8   dog_stage           2297 non-null   object
#  9   dog_breed           2297 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(3), object(6)
# memory usage: 197.4+ KB

# %% [markdown]
# ## Quality archive #7

# %% [markdown]
# ## DEFINE

# %% [raw]
# Replace the source string with the display portion of itself. Extract the string between <a href=""> and </a>.

# %% [markdown]
# ## CODE

# %%
dftwittercopy.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
dftwittercopy['source'] = dftwittercopy['source'].str.extract('^<a.+>(.+)</a>$')
# Out:
# C:\Users\derae\AppData\Local\Temp\ipykernel_11208\3281299431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftwittercopy['source'] = dftwittercopy['source'].str.extract('^<a.+>(.+)</a>$')

# %% [markdown]
# ## TEST

# %%
dftwittercopy.source.value_counts()
# Out:
# Twitter for iPhone     2221
# Vine - Make a Scene      91
# Twitter Web Client       33
# TweetDeck                11
# Name: source, dtype: int64

# %% [markdown]
# ## Image Predictions

# %% [markdown]
# ## QUALITY #8

# %% [markdown]
# ## DEFINE

# %% [markdown]
# Change the first letters of the name p1,p2,p3 columns

# %% [markdown]
# ## CODE

# %%
dfimagecopy.p1 = dfimagecopy.p1.str.capitalize()
dfimagecopy.p2 = dfimagecopy.p2.str.capitalize()
dfimagecopy.p3 = dfimagecopy.p3.str.capitalize()

# %% [markdown]
# ## TEST

# %%
dfimagecopy.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              Collie
# 1        1                 Redbone  0.506826    True  Miniature_pinscher
# 2        1         German_shepherd  0.596461    True            Malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             Redbone
# 4        1      Miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           Bloodhound  0.116197    True
# 3  0.360687    True   Miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %% [markdown]
# Fix "_" and "-" by replacing with space in p1,p2 and p3 columns

# %%
dfimagecopy.p1 = dfimagecopy.p1.str.replace('_',' ')
dfimagecopy.p2 = dfimagecopy.p2.str.replace('_',' ')
dfimagecopy.p3 = dfimagecopy.p3.str.replace('_',' ')

dfimagecopy.p1 = dfimagecopy.p1.str.replace('-',' ')
dfimagecopy.p2 = dfimagecopy.p2.str.replace('-',' ')
dfimagecopy.p3 = dfimagecopy.p3.str.replace('-',' ')

# %%
dfimagecopy.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh springer spaniel  0.465074    True              Collie
# 1        1                 Redbone  0.506826    True  Miniature pinscher
# 2        1         German shepherd  0.596461    True            Malinois
# 3        1     Rhodesian ridgeback  0.408143    True             Redbone
# 4        1      Miniature pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian ridgeback  0.072010    True
# 2  0.138584    True           Bloodhound  0.116197    True
# 3  0.360687    True   Miniature pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %% [markdown]
# # JSON File

# %% [markdown]
# ## QUALITY #9

# %% [markdown]
# ## DEFINE

# %% [markdown]
# set the tweet _id to string with astype()

# %% [markdown]
# ## CODE

# %%
dfjtweetcopy['tweet_id'] = dfjtweetcopy['tweet_id'].astype('str')

# %%
dfjtweetcopy.head()
# Out:
#              tweet_id  favorite_count  retweet_count
# 0  892420643555336193           39467           8853
# 1  892177421306343426           33819           6514
# 2  891815181378084864           25461           4328
# 3  891689557279858688           42908           8964
# 4  891327558926688256           41048           9774

# %% [markdown]
# - Renaming the column names. This will be of help when we wish to merge the data

# %%
dfjtweetcopy.rename(columns = {'favorite_count': 'likes', 'retweet_count': 'retweets'}, inplace = True)

# %% [markdown]
# ## TEST

# %%
dfjtweetcopy.head()
# Out:
#              tweet_id  likes  retweets
# 0  892420643555336193  39467      8853
# 1  892177421306343426  33819      6514
# 2  891815181378084864  25461      4328
# 3  891689557279858688  42908      8964
# 4  891327558926688256  41048      9774

# %%
dfjtweetcopy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2354 non-null   object
#  1   likes     2354 non-null   int64
#  2   retweets  2354 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 55.3+ KB

# %%
dfjtweetcopy.describe()
# Out:
#                likes      retweets
# count    2354.000000   2354.000000
# mean     8080.968564   3164.797366
# std     11814.771334   5284.770364
# min         0.000000      0.000000
# 25%      1415.000000    624.500000
# 50%      3603.500000   1473.500000
# 75%     10122.250000   3652.000000
# max    132810.000000  79515.000000

# %% [markdown]
# ## DEFINE

# %% [markdown]
# - Change tweet_id from number to string for all data set. This will help when we will be merging the data. For consistency.

# %% [markdown]
# ## CODE

# %%
# Change format type from number to string for all

dftwittercopy['tweet_id'] = dftwittercopy['tweet_id'].astype('str')
dfimagecopy['tweet_id'] = dfimagecopy['tweet_id'].astype('str')
dfjtweetcopy['tweet_id'] = dfjtweetcopy['tweet_id'].astype('str')

# %% [markdown]
# ## TEST

# %%
type(dftwittercopy['tweet_id'].iloc[0])
type(dfimagecopy['tweet_id'].iloc[0])
type(dfjtweetcopy['tweet_id'].iloc[0])
# Out:
# str

# %% [markdown]
# ---

# %% [markdown]
# # Step 4: Storing and Merging Data

# %%
dfmerge = pd.merge(dftwittercopy, dfimagecopy, on = ['tweet_id'], how = 'inner')
dfmerge = pd.merge(dfmerge, dfjtweetcopy, on = 'tweet_id', how = 'inner')

# %% [markdown]
# We have just combined all the data set into one frame

# %%
dfmerge.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
# 1 2017-08-01 00:17:27+00:00
# 2 2017-07-31 00:18:03+00:00
# 3 2017-07-30 15:58:51+00:00
# 4 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaT
# 1                       NaN                        NaT
# 2                       NaN                        NaT
# 3                       NaN                        NaT
# 4                       NaN                        NaT
#
#                                        expanded_urls  ...   p1_conf  p1_dog  \
# 0  https://twitter.com/dog_rates/status/892420643...  ...  0.097049   False
# 1  https://twitter.com/dog_rates/status/892177421...  ...  0.323581    True
# 2  https://twitter.com/dog_rates/status/891815181...  ...  0.716012    True
# 3  https://twitter.com/dog_rates/status/891689557...  ...  0.170278   False
# 4  https://twitter.com/dog_rates/status/891327558...  ...  0.555712    True
#
#                    p2   p2_conf p2_dog                           p3   p3_conf  \
# 0               Bagel  0.085851  False                       Banana  0.076110
# 1            Pekinese  0.090647   True                     Papillon  0.068957
# 2            Malamute  0.078253   True                       Kelpie  0.031379
# 3  Labrador retriever  0.168086   True                      Spatula  0.040836
# 4    English springer  0.225770   True  German short haired pointer  0.175219
#
#    p3_dog  likes retweets
# 0   False  39467     8853
# 1    True  33819     6514
# 2    True  25461     4328
# 3   False  42908     8964
# 4    True  41048     9774
#
# [5 rows x 27 columns]

# %%
dfmerge.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2068  666049248165822465                    NaN                  NaN
# 2069  666044226329800704                    NaN                  NaN
# 2070  666033412701032449                    NaN                  NaN
# 2071  666029285002620928                    NaN                  NaN
# 2072  666020888022790149                    NaN                  NaN
#
#                      timestamp  \
# 2068 2015-11-16 00:24:50+00:00
# 2069 2015-11-16 00:04:52+00:00
# 2070 2015-11-15 23:21:54+00:00
# 2071 2015-11-15 23:05:30+00:00
# 2072 2015-11-15 22:32:08+00:00
#
#                                                  source  \
# 2068  <a href="http://twitter.com/download/iphone" r...
# 2069  <a href="http://twitter.com/download/iphone" r...
# 2070  <a href="http://twitter.com/download/iphone" r...
# 2071  <a href="http://twitter.com/download/iphone" r...
# 2072  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2068  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2069  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2070  Here is a very happy pup. Big fan of well-main...                  NaN
# 2071  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2072  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 2068                       NaN                        NaT
# 2069                       NaN                        NaT
# 2070                       NaN                        NaT
# 2071                       NaN                        NaT
# 2072                       NaN                        NaT
#
#                                           expanded_urls  ...   p1_conf  \
# 2068  https://twitter.com/dog_rates/status/666049248...  ...  0.560311
# 2069  https://twitter.com/dog_rates/status/666044226...  ...  0.408143
# 2070  https://twitter.com/dog_rates/status/666033412...  ...  0.596461
# 2071  https://twitter.com/dog_rates/status/666029285...  ...  0.506826
# 2072  https://twitter.com/dog_rates/status/666020888...  ...  0.465074
#
#       p1_dog                  p2   p2_conf p2_dog                   p3  \
# 2068    True          Rottweiler  0.243682   True             Doberman
# 2069    True             Redbone  0.360687   True   Miniature pinscher
# 2070    True            Malinois  0.138584   True           Bloodhound
# 2071    True  Miniature pinscher  0.074192   True  Rhodesian ridgeback
# 2072    True              Collie  0.156665   True    Shetland sheepdog
#
#        p3_conf  p3_dog  likes retweets
# 2068  0.154629    True    111       41
# 2069  0.222752    True    311      147
# 2070  0.116197    True    128       47
# 2071  0.072010    True    132       48
# 2072  0.061428    True   2535      532
#
# [5 rows x 27 columns]

# %%
dfmerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2073 entries, 0 to 2072
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2073 non-null   object
#  1   in_reply_to_status_id       23 non-null     float64
#  2   in_reply_to_user_id         23 non-null     float64
#  3   timestamp                   2073 non-null   datetime64[ns, UTC]
#  4   source                      2073 non-null   object
#  5   text                        2073 non-null   object
#  6   retweeted_status_id         79 non-null     float64
#  7   retweeted_status_user_id    79 non-null     float64
#  8   retweeted_status_timestamp  79 non-null     datetime64[ns, UTC]
#  9   expanded_urls               2073 non-null   object
#  10  rating_numerator            2073 non-null   int64
#  11  rating_denominator          2073 non-null   int64
#  12  name                        2073 non-null   object
#  13  dog_stage                   2073 non-null   object
#  14  jpg_url                     2073 non-null   object
#  15  img_num                     2073 non-null   int64
#  16  p1                          2073 non-null   object
#  17  p1_conf                     2073 non-null   float64
#  18  p1_dog                      2073 non-null   bool
#  19  p2                          2073 non-null   object
#  20  p2_conf                     2073 non-null   float64
#  21  p2_dog                      2073 non-null   bool
#  22  p3                          2073 non-null   object
#  23  p3_conf                     2073 non-null   float64
#  24  p3_dog                      2073 non-null   bool
#  25  likes                       2073 non-null   int64
#  26  retweets                    2073 non-null   int64
# dtypes: bool(3), datetime64[ns, UTC](2), float64(7), int64(5), object(10)
# memory usage: 411.0+ KB

# %% [markdown]
# ### Value of Rating

# %%
dfmerge['rating'] = dfmerge['rating_numerator']/dfmerge['rating_denominator']

# %%
dfmerge.head(1)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaT
#
#                                        expanded_urls  ...  p1_dog     p2  \
# 0  https://twitter.com/dog_rates/status/892420643...  ...   False  Bagel
#
#     p2_conf p2_dog      p3  p3_conf p3_dog  likes  retweets rating
# 0  0.085851  False  Banana  0.07611  False  39467      8853    1.3
#
# [1 rows x 28 columns]

# %% [markdown]
# Lets drop some unwanted columns in our new dataset

# %%
# Drop some unwanted columns
dfmerge.drop(['retweeted_status_id','retweeted_status_timestamp', 'retweeted_status_user_id'], axis = 1, inplace = True)

#Allow all columns and text to be shown
pd.set_option('display.max_columns', None)

# %%
dfmerge.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
# 1 2017-08-01 00:17:27+00:00
# 2 2017-07-31 00:18:03+00:00
# 3 2017-07-30 15:58:51+00:00
# 4 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name dog_stage  \
# 0                  10   Phineas      None
# 1                  10     Tilly      None
# 2                  10    Archie      None
# 3                  10     Darla      None
# 4                  10  Franklin      None
#
#                                            jpg_url  img_num           p1  \
# 0  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg        1       Orange
# 1  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg        1    Chihuahua
# 2  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg        1    Chihuahua
# 3  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg        1  Paper towel
# 4  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg        2       Basset
#
#     p1_conf  p1_dog                  p2   p2_conf  p2_dog  \
# 0  0.097049   False               Bagel  0.085851   False
# 1  0.323581    True            Pekinese  0.090647    True
# 2  0.716012    True            Malamute  0.078253    True
# 3  0.170278   False  Labrador retriever  0.168086    True
# 4  0.555712    True    English springer  0.225770    True
#
#                             p3   p3_conf  p3_dog  likes  retweets  rating
# 0                       Banana  0.076110   False  39467      8853     1.3
# 1                     Papillon  0.068957    True  33819      6514     1.3
# 2                       Kelpie  0.031379    True  25461      4328     1.2
# 3                      Spatula  0.040836   False  42908      8964     1.3
# 4  German short haired pointer  0.175219    True  41048      9774     1.2

# %%
dfmerge.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2068  666049248165822465                    NaN                  NaN
# 2069  666044226329800704                    NaN                  NaN
# 2070  666033412701032449                    NaN                  NaN
# 2071  666029285002620928                    NaN                  NaN
# 2072  666020888022790149                    NaN                  NaN
#
#                      timestamp  \
# 2068 2015-11-16 00:24:50+00:00
# 2069 2015-11-16 00:04:52+00:00
# 2070 2015-11-15 23:21:54+00:00
# 2071 2015-11-15 23:05:30+00:00
# 2072 2015-11-15 22:32:08+00:00
#
#                                                  source  \
# 2068  <a href="http://twitter.com/download/iphone" r...
# 2069  <a href="http://twitter.com/download/iphone" r...
# 2070  <a href="http://twitter.com/download/iphone" r...
# 2071  <a href="http://twitter.com/download/iphone" r...
# 2072  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 2068  Here we have a 1949 1st generation vulpix. Enj...
# 2069  This is a purebred Piers Morgan. Loves to Netf...
# 2070  Here is a very happy pup. Big fan of well-main...
# 2071  This is a western brown Mitsubishi terrier. Up...
# 2072  Here we have a Japanese Irish Setter. Lost eye...
#
#                                           expanded_urls  rating_numerator  \
# 2068  https://twitter.com/dog_rates/status/666049248...                 5
# 2069  https://twitter.com/dog_rates/status/666044226...                 6
# 2070  https://twitter.com/dog_rates/status/666033412...                 9
# 2071  https://twitter.com/dog_rates/status/666029285...                 7
# 2072  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  name dog_stage  \
# 2068                  10  None      None
# 2069                  10  None      None
# 2070                  10  None      None
# 2071                  10  None      None
# 2072                  10  None      None
#
#                                               jpg_url  img_num  \
# 2068  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg        1
# 2069  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg        1
# 2070  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg        1
# 2071  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg        1
# 2072  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg        1
#
#                           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2068      Miniature pinscher  0.560311    True          Rottweiler  0.243682
# 2069     Rhodesian ridgeback  0.408143    True             Redbone  0.360687
# 2070         German shepherd  0.596461    True            Malinois  0.138584
# 2071                 Redbone  0.506826    True  Miniature pinscher  0.074192
# 2072  Welsh springer spaniel  0.465074    True              Collie  0.156665
#
#       p2_dog                   p3   p3_conf  p3_dog  likes  retweets  rating
# 2068    True             Doberman  0.154629    True    111        41     0.5
# 2069    True   Miniature pinscher  0.222752    True    311       147     0.6
# 2070    True           Bloodhound  0.116197    True    128        47     0.9
# 2071    True  Rhodesian ridgeback  0.072010    True    132        48     0.7
# 2072    True    Shetland sheepdog  0.061428    True   2535       532     0.8

# %% [markdown]
# ## Data Storing

# %%
dfmerge.to_csv('twitter_archieve_master_new.csv', encoding = 'utf-8', index = False)

# %%
# Read our new data
dfwragled = pd.read_csv('twitter_archieve_master_new.csv')

# %%
dfwragled.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56+00:00
# 1  2017-08-01 00:17:27+00:00
# 2  2017-07-31 00:18:03+00:00
# 3  2017-07-30 15:58:51+00:00
# 4  2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name dog_stage  \
# 0                  10   Phineas      None
# 1                  10     Tilly      None
# 2                  10    Archie      None
# 3                  10     Darla      None
# 4                  10  Franklin      None
#
#                                            jpg_url  img_num           p1  \
# 0  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg        1       Orange
# 1  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg        1    Chihuahua
# 2  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg        1    Chihuahua
# 3  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg        1  Paper towel
# 4  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg        2       Basset
#
#     p1_conf  p1_dog                  p2   p2_conf  p2_dog  \
# 0  0.097049   False               Bagel  0.085851   False
# 1  0.323581    True            Pekinese  0.090647    True
# 2  0.716012    True            Malamute  0.078253    True
# 3  0.170278   False  Labrador retriever  0.168086    True
# 4  0.555712    True    English springer  0.225770    True
#
#                             p3   p3_conf  p3_dog  likes  retweets  rating
# 0                       Banana  0.076110   False  39467      8853     1.3
# 1                     Papillon  0.068957    True  33819      6514     1.3
# 2                       Kelpie  0.031379    True  25461      4328     1.2
# 3                      Spatula  0.040836   False  42908      8964     1.3
# 4  German short haired pointer  0.175219    True  41048      9774     1.2

# %%
dfwragled.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2068  666049248165822465                    NaN                  NaN
# 2069  666044226329800704                    NaN                  NaN
# 2070  666033412701032449                    NaN                  NaN
# 2071  666029285002620928                    NaN                  NaN
# 2072  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2068  2015-11-16 00:24:50+00:00
# 2069  2015-11-16 00:04:52+00:00
# 2070  2015-11-15 23:21:54+00:00
# 2071  2015-11-15 23:05:30+00:00
# 2072  2015-11-15 22:32:08+00:00
#
#                                                  source  \
# 2068  <a href="http://twitter.com/download/iphone" r...
# 2069  <a href="http://twitter.com/download/iphone" r...
# 2070  <a href="http://twitter.com/download/iphone" r...
# 2071  <a href="http://twitter.com/download/iphone" r...
# 2072  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 2068  Here we have a 1949 1st generation vulpix. Enj...
# 2069  This is a purebred Piers Morgan. Loves to Netf...
# 2070  Here is a very happy pup. Big fan of well-main...
# 2071  This is a western brown Mitsubishi terrier. Up...
# 2072  Here we have a Japanese Irish Setter. Lost eye...
#
#                                           expanded_urls  rating_numerator  \
# 2068  https://twitter.com/dog_rates/status/666049248...                 5
# 2069  https://twitter.com/dog_rates/status/666044226...                 6
# 2070  https://twitter.com/dog_rates/status/666033412...                 9
# 2071  https://twitter.com/dog_rates/status/666029285...                 7
# 2072  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  name dog_stage  \
# 2068                  10  None      None
# 2069                  10  None      None
# 2070                  10  None      None
# 2071                  10  None      None
# 2072                  10  None      None
#
#                                               jpg_url  img_num  \
# 2068  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg        1
# 2069  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg        1
# 2070  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg        1
# 2071  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg        1
# 2072  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg        1
#
#                           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2068      Miniature pinscher  0.560311    True          Rottweiler  0.243682
# 2069     Rhodesian ridgeback  0.408143    True             Redbone  0.360687
# 2070         German shepherd  0.596461    True            Malinois  0.138584
# 2071                 Redbone  0.506826    True  Miniature pinscher  0.074192
# 2072  Welsh springer spaniel  0.465074    True              Collie  0.156665
#
#       p2_dog                   p3   p3_conf  p3_dog  likes  retweets  rating
# 2068    True             Doberman  0.154629    True    111        41     0.5
# 2069    True   Miniature pinscher  0.222752    True    311       147     0.6
# 2070    True           Bloodhound  0.116197    True    128        47     0.9
# 2071    True  Rhodesian ridgeback  0.072010    True    132        48     0.7
# 2072    True    Shetland sheepdog  0.061428    True   2535       532     0.8

# %%
dfwragled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               2073 non-null   int64
#  1   in_reply_to_status_id  23 non-null     float64
#  2   in_reply_to_user_id    23 non-null     float64
#  3   timestamp              2073 non-null   object
#  4   source                 2073 non-null   object
#  5   text                   2073 non-null   object
#  6   expanded_urls          2073 non-null   object
#  7   rating_numerator       2073 non-null   int64
#  8   rating_denominator     2073 non-null   int64
#  9   name                   2073 non-null   object
#  10  dog_stage              2073 non-null   object
#  11  jpg_url                2073 non-null   object
#  12  img_num                2073 non-null   int64
#  13  p1                     2073 non-null   object
#  14  p1_conf                2073 non-null   float64
#  15  p1_dog                 2073 non-null   bool
#  16  p2                     2073 non-null   object
#  17  p2_conf                2073 non-null   float64
#  18  p2_dog                 2073 non-null   bool
#  19  p3                     2073 non-null   object
#  20  p3_conf                2073 non-null   float64
#  21  p3_dog                 2073 non-null   bool
#  22  likes                  2073 non-null   int64
#  23  retweets               2073 non-null   int64
#  24  rating                 2073 non-null   float64
# dtypes: bool(3), float64(6), int64(6), object(10)
# memory usage: 362.5+ KB

# %%
dfwragled.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.073000e+03           2.300000e+01         2.300000e+01
# mean   7.383634e+17           6.978112e+17         4.196984e+09
# std    6.780118e+16           4.359384e+16         0.000000e+00
# min    6.660209e+17           6.671522e+17         4.196984e+09
# 25%    6.764706e+17           6.732411e+17         4.196984e+09
# 50%    7.119681e+17           6.757073e+17         4.196984e+09
# 75%    7.931959e+17           7.031489e+17         4.196984e+09
# max    8.924206e+17           8.558181e+17         4.196984e+09
#
#        rating_numerator  rating_denominator      img_num      p1_conf  \
# count       2073.000000              2073.0  2073.000000  2073.000000
# mean          12.265798                10.0     1.203570     0.594532
# std           40.699924                 0.0     0.561856     0.271234
# min            0.000000                10.0     1.000000     0.044333
# 25%           10.000000                10.0     1.000000     0.364095
# 50%           11.000000                10.0     1.000000     0.588230
# 75%           12.000000                10.0     1.000000     0.843911
# max         1776.000000                10.0     4.000000     1.000000
#
#             p2_conf       p3_conf          likes      retweets       rating
# count  2.073000e+03  2.073000e+03    2073.000000   2073.000000  2073.000000
# mean   1.346665e-01  6.034005e-02    8556.718283   2976.089243     1.226580
# std    1.006830e-01  5.092769e-02   12098.640994   5054.897526     4.069992
# min    1.011300e-08  1.740170e-10       0.000000     16.000000     0.000000
# 25%    5.390140e-02  1.619920e-02    1674.000000    634.000000     1.000000
# 50%    1.186220e-01  4.947150e-02    3864.000000   1408.000000     1.100000
# 75%    1.955730e-01  9.193000e-02   10937.000000   3443.000000     1.200000
# max    4.880140e-01  2.734190e-01  132810.000000  79515.000000   177.600000

# %%
dfwragled.shape
# Out:
# (2073, 25)

# %% [markdown]
# ---

# %% [markdown]
# # Step 5: Analyzing, and visualizing data

# %%
dfwragled.loc[dfwragled['rating']>2]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 345   820690176645140481                    NaN                  NaN
# 415   810984652412424192                    NaN                  NaN
# 558   786709082849828864                    NaN                  NaN
# 614   778027034220126208                    NaN                  NaN
# 734   758467244762497024                    NaN                  NaN
# 802   749981277374128128                    NaN                  NaN
# 924   731156023742988288                    NaN                  NaN
# 1001  716439118184652801                    NaN                  NaN
# 1022  713900603437621249                    NaN                  NaN
# 1047  710658690886586372                    NaN                  NaN
# 1065  709198395643068416                    NaN                  NaN
# 1131  704054845121142784                    NaN                  NaN
# 1207  697463031882764288                    NaN                  NaN
# 1379  684225744407494656           6.842229e+17         4.196984e+09
# 1380  684222868335505415                    NaN                  NaN
# 1451  680494726643068929                    NaN                  NaN
# 1512  677716515794329600                    NaN                  NaN
# 1571  675853064436391936                    NaN                  NaN
# 1795  670842764863651840                    NaN                  NaN
#
#                       timestamp  \
# 345   2017-01-15 17:52:40+00:00
# 415   2016-12-19 23:06:23+00:00
# 558   2016-10-13 23:23:56+00:00
# 614   2016-09-20 00:24:34+00:00
# 734   2016-07-28 01:00:57+00:00
# 802   2016-07-04 15:00:45+00:00
# 924   2016-05-13 16:15:54+00:00
# 1001  2016-04-03 01:36:11+00:00
# 1022  2016-03-27 01:29:02+00:00
# 1047  2016-03-18 02:46:49+00:00
# 1065  2016-03-14 02:04:08+00:00
# 1131  2016-02-28 21:25:30+00:00
# 1207  2016-02-10 16:51:59+00:00
# 1379  2016-01-05 04:11:44+00:00
# 1380  2016-01-05 04:00:18+00:00
# 1451  2015-12-25 21:06:00+00:00
# 1512  2015-12-18 05:06:23+00:00
# 1571  2015-12-13 01:41:41+00:00
# 1795  2015-11-29 05:52:33+00:00
#
#                                                  source  \
# 345   <a href="http://twitter.com/download/iphone" r...
# 415   <a href="http://twitter.com/download/iphone" r...
# 558   <a href="http://twitter.com/download/iphone" r...
# 614   <a href="http://twitter.com/download/iphone" r...
# 734   <a href="http://twitter.com/download/iphone" r...
# 802   <a href="https://about.twitter.com/products/tw...
# 924   <a href="http://twitter.com/download/iphone" r...
# 1001  <a href="http://twitter.com/download/iphone" r...
# 1022  <a href="http://twitter.com/download/iphone" r...
# 1047  <a href="http://twitter.com/download/iphone" r...
# 1065  <a href="http://twitter.com/download/iphone" r...
# 1131  <a href="http://twitter.com/download/iphone" r...
# 1207  <a href="http://twitter.com/download/iphone" r...
# 1379  <a href="http://twitter.com/download/iphone" r...
# 1380  <a href="http://twitter.com/download/iphone" r...
# 1451  <a href="http://twitter.com/download/iphone" r...
# 1512  <a href="http://twitter.com/download/iphone" r...
# 1571  <a href="http://twitter.com/download/iphone" r...
# 1795  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 345   The floofs have been released I repeat the flo...
# 415   Meet Sam. She smiles 24/7 &amp; secretly aspir...
# 558   This is Logan, the Chow who lived. He solemnly...
# 614   This is Sophie. She's a Jubilant Bush Pupper. ...
# 734   Why does this never happen at my front door......
# 802   This is Atticus. He's quite simply America af....
# 924   Say hello to this unbelievably well behaved sq...
# 1001  This is Bluebert. He just saw that both #Final...
# 1022  Happy Saturday here's 9 puppers on a bench. 99...
# 1047  Here's a brigade of puppers. All look very pre...
# 1065  From left to right:\nCletus, Jerome, Alejandro...
# 1131  Here is a whole flock of puppers.  60/50 I'll ...
# 1207  Happy Wednesday here's a bucket of pups. 44/40...
# 1379  Two sneaky puppers were not initially seen, mo...
# 1380  Someone help the girl is being mugged. Several...
# 1451  Here we have uncovered an entire battalion of ...
# 1512  IT'S PUPPERGEDDON. Total of 144/120 ...I think...
# 1571  Here we have an entire platoon of puppers. Tot...
# 1795  After so many requests... here you go.\n\nGood...
#
#                                           expanded_urls  rating_numerator  \
# 345   https://twitter.com/dog_rates/status/820690176...                84
# 415   https://www.gofundme.com/sams-smile,https://tw...                24
# 558   https://twitter.com/dog_rates/status/786709082...                75
# 614   https://twitter.com/dog_rates/status/778027034...                27
# 734   https://twitter.com/dog_rates/status/758467244...               165
# 802   https://twitter.com/dog_rates/status/749981277...              1776
# 924   https://twitter.com/dog_rates/status/731156023...               204
# 1001  https://twitter.com/dog_rates/status/716439118...                50
# 1022  https://twitter.com/dog_rates/status/713900603...                99
# 1047  https://twitter.com/dog_rates/status/710658690...                80
# 1065  https://twitter.com/dog_rates/status/709198395...                45
# 1131  https://twitter.com/dog_rates/status/704054845...                60
# 1207  https://twitter.com/dog_rates/status/697463031...                44
# 1379  https://twitter.com/dog_rates/status/684225744...               143
# 1380  https://twitter.com/dog_rates/status/684222868...               121
# 1451  https://twitter.com/dog_rates/status/680494726...                26
# 1512  https://twitter.com/dog_rates/status/677716515...               144
# 1571  https://twitter.com/dog_rates/status/675853064...                88
# 1795  https://twitter.com/dog_rates/status/670842764...               420
#
#       rating_denominator      name dog_stage  \
# 345                   10      None      None
# 415                   10       Sam      None
# 558                   10     Logan      None
# 614                   10    Sophie    pupper
# 734                   10      None      None
# 802                   10   Atticus      None
# 924                   10      None      None
# 1001                  10  Bluebert      None
# 1022                  10      None      None
# 1047                  10      None      None
# 1065                  10      None      None
# 1131                  10      None      None
# 1207                  10      None      None
# 1379                  10      None      None
# 1380                  10      None      None
# 1451                  10      None      None
# 1512                  10      None      None
# 1571                  10      None      None
# 1795                  10      None      None
#
#                                                 jpg_url  img_num  \
# 345     https://pbs.twimg.com/media/C2OtWr0VQAEnS9r.jpg        2
# 415     https://pbs.twimg.com/media/C0EyPZbXAAAceSc.jpg        1
# 558     https://pbs.twimg.com/media/CurzvFTXgAA2_AP.jpg        1
# 614     https://pbs.twimg.com/media/Cswbc2yWcAAVsCJ.jpg        1
# 734   https://pbs.twimg.com/ext_tw_video_thumb/75846...        1
# 802     https://pbs.twimg.com/media/CmgBZ7kWcAAlzFD.jpg        1
# 924     https://pbs.twimg.com/media/CiWWhVNUYAAab_r.jpg        1
# 1001    https://pbs.twimg.com/media/CfFNk7cWAAA-hND.jpg        1
# 1022    https://pbs.twimg.com/media/CehIzzZWQAEyHH5.jpg        1
# 1047    https://pbs.twimg.com/media/CdzETn4W4AAVU5N.jpg        1
# 1065    https://pbs.twimg.com/media/CdeUKpcWoAAJAWJ.jpg        1
# 1131    https://pbs.twimg.com/media/CcVOJEcXEAM0FHL.jpg        1
# 1207    https://pbs.twimg.com/media/Ca3i7CzXIAMLhg8.jpg        1
# 1379    https://pbs.twimg.com/media/CX7br3HWsAAQ9L1.jpg        2
# 1380    https://pbs.twimg.com/media/CX7Y_ByWwAEJdUy.jpg        1
# 1451    https://pbs.twimg.com/media/CXGaVxOWAAADjhF.jpg        1
# 1512    https://pbs.twimg.com/media/CWe7kw9W4AE8UJh.jpg        1
# 1571    https://pbs.twimg.com/media/CWEcxqWVEAAHyGH.jpg        1
# 1795    https://pbs.twimg.com/media/CU9P717W4AAOlKx.jpg        1
#
#                                p1   p1_conf  p1_dog                       p2  \
# 345   West highland white terrier  0.872064    True                   Kuvasz
# 415              Golden retriever  0.871342    True          Tibetan mastiff
# 558                    Pomeranian  0.467321    True              Persian cat
# 614                       Clumber  0.946718    True           Cocker spaniel
# 734            Labrador retriever  0.436377    True                Chihuahua
# 802                       Bow tie  0.533941   False               Sunglasses
# 924                      Lakeside  0.501767   False               Breakwater
# 1001               Siberian husky  0.396495    True                 Malamute
# 1022             Golden retriever  0.371816    True           Cocker spaniel
# 1047  Soft coated wheaten terrier  0.948617    True           Dandie dinmont
# 1065                       Borzoi  0.490783    True  Wire haired fox terrier
# 1131               Great pyrenees  0.667939    True                   Kuvasz
# 1207           Labrador retriever  0.999885    True         Golden retriever
# 1379             Golden retriever  0.203249    True                  Samoyed
# 1380  Soft coated wheaten terrier  0.791182    True           Cocker spaniel
# 1451                       Kuvasz  0.438627    True                  Samoyed
# 1512                        Teddy  0.662908   False                     Crib
# 1571           Labrador retriever  0.868367    True         Golden retriever
# 1795                   Microphone  0.096063   False                Accordion
#
#        p2_conf  p2_dog                              p3   p3_conf  p3_dog  \
# 345   0.059526    True                         Samoyed  0.037400    True
# 415   0.036708    True              Labrador retriever  0.025823    True
# 558   0.122978   False                            Chow  0.102654    True
# 614   0.015950    True                           Lhasa  0.006519    True
# 734   0.113956    True  American staffordshire terrier  0.099689    True
# 802   0.080822   False                        Sunglass  0.050776   False
# 924   0.051351   False                    King penguin  0.049444   False
# 1001  0.317053    True                      Eskimo dog  0.273419    True
# 1022  0.177413    True                    Irish setter  0.092725    True
# 1047  0.018664    True                           Cairn  0.015943    True
# 1065  0.083513    True                  English setter  0.083184    True
# 1131  0.228764    True                Golden retriever  0.043885    True
# 1207  0.000098    True                             Pug  0.000008    True
# 1379  0.067958    True                  Great pyrenees  0.065327    True
# 1380  0.072444    True                           Teddy  0.071486   False
# 1451  0.111622    True                  Great pyrenees  0.064061    True
# 1512  0.031891   False                            Chow  0.025438    True
# 1571  0.043305    True                          Vizsla  0.028207    True
# 1795  0.094075   False                       Drumstick  0.061113   False
#
#       likes  retweets  rating
# 345   13518      3716     8.4
# 415    5927      1655     2.4
# 558   20296      7069     7.5
# 614    7320      1885     2.7
# 734    5316      2539    16.5
# 802    5569      2772   177.6
# 924    4196      1434    20.4
# 1001   2574       247     5.0
# 1022   3062       829     9.9
# 1047   2529       636     8.0
# 1065   2634       721     4.5
# 1131   3201      1028     6.0
# 1207   3748      1552     4.4
# 1379   1369       239    14.3
# 1380   4225      1563    12.1
# 1451   1879       542     2.6
# 1512   3323      1104    14.4
# 1571   2927      1460     8.8
# 1795   7989      4324    42.0

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# New issues Detected

# %%
#Remove links and apply to text
def remove_link(x):
    http_pos =x.find("http")
    if http_pos == -1:
        x = x
    else:
        x = x[:http_pos - 1]
    return x

# %%
dfwragled.text = dfwragled.text.apply(remove_link)

# %%
for row in dfwragled.text[:5]:
    print(row)
# Out:
# This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10
# This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10
# This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10
# This is Darla. She commenced a snooze mid meal. 13/10 happens to the best of us
# This is Franklin. He would like you to stop calling him "cute." He is a very fierce shark and should be respected as such. 12/10 #BarkWeek

# %%
# Word Cloud of text 
#Collect all texts from column 'text'
text1 = " ".join(review for review in dfwragled.text)

#Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["puppy", "Bruno", "dog", "good", "boy", "cool"])

#Generate a word cloud image
wordcloud = WordCloud(stopwords = stopwords, background_color = "white").generate(text1)

# Display the generated image:
# the matplotlib way
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %%
dfwragled.plot(kind = "scatter", x = "likes", y = "retweets", alpha = 0.7, figsize = (7,7), color = 'red')
plt.xlabel('Favorites')
plt.ylabel('Retweets')
plt.title('Retweets and Favorites Plot')
# Out:
# Text(0.5, 1.0, 'Retweets and Favorites Plot')

# %%
plt.figure(figsize = (10, 10))
g = sns.boxplot(x = 'dog_stage', y ='retweets', data = dfwragled, palette = 'spring')
g.axes.set_title('Boxplot between dog stages and retweet', fontsize = 16);

# %% [markdown]
# This actually shows that most of the dogs are in Puppo category but highest retweets are about doggo category

# %%
sns.pairplot(dfwragled,
             vars = ['rating', 'retweets', 'likes', 'rating'],
             diag_kind = 'kde', plot_kws = {'alpha': 0.2});

# %% [markdown]
# What dog stage have the highest overall likes

# %%
likes_breed = dfwragled[dfwragled.dog_stage != 'None']
likes_breed = likes_breed.groupby(['dog_stage'])
likes_breed = likes_breed['likes'].sum()
likes_breed = likes_breed.sort_values(ascending = False)
top10_likes_breeds = likes_breed.head(10)
top10_likes_breeds
# Out:
# dog_stage
# pupper           1461141
# doggo            1219452
# puppo             474806
# doggo,pupper      112798
# floofer            92442
# doggo,puppo        47844
# doggo,floofer      17169
# Name: likes, dtype: int64

# %%
plt.barh(top10_likes_breeds.index, top10_likes_breeds, color = 'g')

plt.xlabel('Aggregate Favorite Count', fontsize = 14)

# plt.ylabel('Dog Breed', fontsize = 12)
plt.title('Top 10 Dog Stage by Aggregate Likes', fontsize = 16)
plt.gca().invert_yaxis()
plt.show();

# %% [markdown]
# Pupper has the highest likes
